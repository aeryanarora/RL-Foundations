# %% [markdown]
# # CS780: Deep Reinforcement Learning Assignment - 2
# ***Instructor: Ashutosh Modi***
#
#
# - Submission Deadline: 11:59PM, February 22nd, 2026
# - Submission Link: [https://forms.gle/sVsreFguMKG1GfQD7](https://forms.gle/sVsreFguMKG1GfQD7)

# %% [markdown]
# Name: Aryan Arora
#
# Roll No.: 251110016
#
# IITK EMail: aryana25@iitk.ac.in

# %% [markdown]
# ## Instructions
# Read all the instructions below carefully before you start working on the assignment.
#
#
# • The purpose of this course is that you learn RL and the best way to do that is by implementation and
# experimentation.
#
# • The assignment requires your to implement some algorithms and you are required report your findings
# after experimenting with those algorithms. The report should be submitted in pdf format.
#
# • Implement the code in this Google Colab Notebook and write your findings and observations in markdown cells to create a complete report
#
# • In case you use any maths in your explanations, render it using latex in the notebook.
#
# • You are expected to implement algorithms on your own and not copy it from other sources/class mates.
# Of course, you can refer to lecture slides.
#
# • If you use any reference or material (including code), please cite the source, else it will be considered
# plagiarism. But referring to other sources that directly solve the problems given in the assignment is not
# allowed. There is a limit to which you can refer to outside material.
#
# • This is an individual assignment.
#
# • In case your solution is found to have an overlap with solution by someone else (including external sources),
# all the parties involved will get zero in this and all future assignments plus further more penalties in the
# overall grade. We will check not just for lexical but also semantic overlap. Same applies for the code as
# well. Even an iota of cheating would NOT be tolerated. If you cheat one line or cheat one page
# the penalty would be same.
#
# • Be a smart agent, think long term, if you cheat we will discover it somehow, the price you would be paying
# is not worth it.
#
# • In case you are struggling with the assignment, seek help from TAs. Cheating is not an option! I respect
# honesty and would be lenient if you are not able to solve some questions due to difficulty in understanding.
# Remember we are there to help you out, seek help if something is difficult to understand.
#
# • The deadline for the submission is given above. Submit at least 30 minutes before the deadline, lot can
# happen at the last moment, your internet can fail, there can be a power failure, you can be abducted by
# aliens, etc.
#
# • You have to submit your assignment via a Google Form (link above)
#
# • The form would close after the deadline and we will not accept any solution. No reason what-so-ever
# would be accepted for not being able to submit before the deadline.
#
# • Since the assignment involves experimentation, reporting your results and observations, there is a lot
# of scope for creativity and innovation and presenting new perspectives. Such efforts would be highly
# appreciated and accordingly well rewarded. Be an exploratory agent!
#
# • Your code should be very well documented, there are marks for that.
#
# • In your plots, have a clear legend and clear lines, etc. Of course you would generating the plots in your
# code but you must also put these plots in your notebook. Generate high resolution pdf/svg version of the
# plots so that it doesn’t pixilate on zooming.
#
# • For all experiments, report about the seed used in the code documentation, write about the seed used.
#
# • In your notebook write about all things that are not obvious from the code e.g., if you have made any
# assumptions, references/sources, running time, etc.
#
# <font color = red><b>
#
# • In addition to checking your code and report, very likely, we will be conducting one-on-one
# viva for the evaluation. So please make sure that you do not cheat!
# </font></b>
#
# <font color = red><b>
# • If you use LLMs or LLM based tools (also refer to usage policy below) for coding or for any other purpose, please declare it very clearly in your solution (see the declaration form below). You need to answer questions like: What was the LLM used for? What was your contibution after the LLM usage? Any other information that shows that despite using the LLM you did make contibutions to the assignment, things like analysis, etc. Failure to declare would taken as cheating/plagiarism and will be very heavily penalized.
# </font></b>

# %% [markdown]
# # LLM Usage Policy
#
# It is **OK** to use LLM or other sources (websites, blogs, books, etc) for:
# * Coding ancillary parts of the algorithm such as plotting graphs, etc.
# * To develop understanding of the algorithm in the case it is not clear to you
#
# It is **NOT OK** to use LLM or other sources (websites, blogs, books, etc) for:
# * Writing the code for the main parts of the algorithm especially given that I have already provided pseudo-code in the lectures. (You can use pseudo code as it is from the lecture slides)
# * For doing hyper-parameter tuning of the algorithm.
# * For doing analysis of the results and drawing conclusions about it
#
# Since RL is specialized domain, it is very straight forward to detect when someone (especially a newbie) is taking code from LLM or other sources. In case you are found to do so (even for a small part of assignment), there will be no questions asked direct zero will be awarded to you along with further penalties which will affect your final grade.
#
# Be a smart agent (remember Honesty is the best Policy), it is ok to loose a few marks than getting a zero + penalties. It is OK if you don't do all questions in the assignment which will cost you a few marks vs getting 0.
#
# **Remember that grading is relative and you are not the only one who is finding it tough!**

# %% [markdown]
# # LLM Usage Declaration
#
# It is permitted to use Large Language Models (LLMs) **only for understanding concepts, ideation, and creating initial code stubs**.
# Using an LLM to **completely solve the assignment is not allowed**.
#
# Even if an LLM is used for the permitted purposes, you **must be able to clearly explain the solution without any LLM assistance during the viva**, if called.
#
# ---
#
# ### Q1. **Which Large Language Model (LLM) did you use to complete this assignment?**
#
# > Claude , Gemini(unintentionally)
#
# ---
#
# ### Q2. **In which questions did you use the LLM, and how did it help you?**
# (You may extend this table by adding more rows if needed.)
#
# | Question Number / Sub-part | Used LLM? (Yes/No) | Purpose of Using LLM (e.g., ideation, explanation, code stub, grammar) | Brief Description of LLM Contribution |
# |----------------------------|--------------------|------------------------------------------------------------------------|-------------------------------------|
# | Plotting                       |  Yes                   |  For creating the diagram for maze_environment, and adjusting legends of plots                                                                      |                                     |
# | Handling Truncation                         |  Yes                  |  For passing max_steps as options, so that whenever environment is reset, max_steps can be varied, if required                                                                      |                                     |
# | Rest of the Assignment Q1-Q11|   No                 |                                                                        |   |
# | Syntactical Numpy Errors | Yes | Resolving numpy syntax errors found via Google (Gemini results) |
# |
#
# ---
#
# ### Q3. **Did you refer to any other sources or websites apart from the LLM and lecture slides?**
#
# If yes, please mention the source(s) clearly:
# > Gymnasium website for environment registering
#
# ---
#
# ### Q4. **Apart from using any LLM, what was your own contribution while solving this assignment?**
#
# Briefly describe:
# - Your understanding of the concepts
# - The reasoning you applied
# - Any implementation or analysis done independently
#
# > I went through the lecture notes, understood the algorithms, and implemented them on my own.
# > The analysis of the plots was done while referring to lecture slides and notes.
# > All implementations were done independently.
#
# ---

# %% [markdown]
# # OpenAI Gym Environments
# <a id="Environment"></a>

# %%
# all imports go in here
import gymnasium as gym
from gymnasium import spaces, Env
from gymnasium.envs.registration import register
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# ## **Random-Maze Environment**

# %% [markdown]
# **In this assignment we will be exploring a variant of the Random Maze Environment (RME) that we have been looking in the lectures.**

# %% [markdown]
# The environment is represented as a grid world in Figure 1a. Random maze environment
# is a highly stochastic environment with 11 states: two terminal states (a goal state (G) and a hole state (H))
# and 9 non-terminal states and a wall in between the environment. The wall behaves similar to the wall on the
# periphery of the environment, basically if an agent bumps against the wall, it bounces back. The boundary of
# the environment behaves similarly, if an agent hits the boundary it bounces back. The agent receives a reward
# of +1 when it lands in the goal state (3) and it receives a reward of -1 when it lands in the hole state (7).
# For rest of the transitions there is a reward of -0.04. Essentially the agent has the living cost of -0.04.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The transitions are stochastic as shown in Figure 1b. In this environment, four actions are possible: left, top, right,
# and bottom. For every intended action, there is 80% chance of going in the intended direction and remaining
# 20% chances of going in either of the orthogonal directions. The 20% chance gets equally distributed between
# each of the orthogonal direction. The agent starts from state 8 (S). Assume γ = 0.99 for the problems below.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In this assignment we will be looking at control algorithms we learnt in Lectures. For each of the plot, create
# the legend on the left/right side so that it doesn’t overlay on the plot. For all the algorithms below,
# this time we will not be specifying the hyper-parameters, please play with the hyper-params to come up with
# the best values. This way you will learn to tune the model. As you are aware from your past experience, single
# run of the algorithm over the environment results in plots that have lot of variance and look very noisy. One
# way to overcome this is to create several different instances of the environment using different seeds and then
# average out the results across these and plot these. For all the plots below, use this strategy.

# %% [markdown]
# # Create the Maze Environment

# %%
class SlipperyMaze(Env):
    """
    A stochastic grid-based maze environment where actions may result
    in unintended movements due to slippery transitions.
    """

    def __init__(self, config=None):
        """
        Initializes the Slippery Maze Environment.

        Args:
            config (dict or None):
                A configuration dictionary containing environment parameters.
                It includes maze dimensions, number of states and actions,
                start, goal, wall, and hole states, reward values, and
                random seed information.

        Returns:
            None
        """
        super().__init__()
        
        self.rows = config['environment']['maze_shape'][0]
        self.cols = config['environment']['maze_shape'][1]
        self.states = config['environment']['total_states']
        self.start_state = config['environment']['start_state']
        self.current_state = self.start_state
        self.hole_state = config['environment']['hole_state']
        self.goal_state = config['environment']['goal_state']
        self.goal_reward = config['environment']['goal_reward']
        self.hole_reward = config['environment']['hole_reward']
        self.living_reward = config['environment']['living_reward']
        self.wall_state = config['environment']['wall_state']
        self.P = self._make_environment(config)
        self.info = {}
        self.max_steps = None
        self.steps = 0

        self.action_space = spaces.Discrete(config['environment']['total_actions'])
        self.observation_space = spaces.Discrete(config['environment']['total_states'])
        

    def _make_environment(self, config):
        """
        Creates the transition probability model for the maze.

        Args:
            config (dict):
                Dictionary defining the maze layout, total states,
                total actions, maze shape, wall locations, and reward
                specifications.

        Returns:
            dict:
                A transition dictionary P such that:
                P[state][action] is a list of tuples
                (probability, next_state, reward, terminated),
                describing the stochastic outcome of taking an action
                in a given state.
        """
        P = {}
        rows = self.rows
        cols = self.cols
        for x in range(rows):
            for y in range(cols):
                state = (x*cols) + y
                P[state] = {}
                if state == self.wall_state:
                    P[state][0] = []
                    P[state][1] = []
                    P[state][2] = []
                    P[state][3] = []
                    continue
                if state == self.goal_state or state == self.hole_state:
                    P[state][0] = [(1,state,0,True)]
                    P[state][1] = [(1,state,0,True)]
                    P[state][2] = [(1,state,0,True)]
                    P[state][3] = [(1,state,0,True)]
                    continue
                    
                    
                if x == 0:
                    state_up = state
                else: 
                    state_up = ((x-1)*cols) + y
                    if state_up == self.wall_state:
                        state_up = state
                
                if x == rows - 1:
                    state_down = state
                else:
                    state_down = ((x+1)*cols) + y
                    if state_down == self.wall_state: 
                        state_down = state
                    
                if y == 0:
                    state_left = state
                else:
                    state_left = state-1
                    if state_left == self.wall_state:
                        state_left = state
                    
                if y == cols - 1:
                    state_right = state
                else:
                    state_right = state+1
                    if state_right == self.wall_state:
                        state_right = state

                if state_up == self.hole_state:
                    reward_up = self.hole_reward
                    term_up = True
                elif state_up == self.goal_state:
                    reward_up = self.goal_reward
                    term_up = True
                else:
                    reward_up = self.living_reward
                    term_up = False
                    
                if state_down == self.hole_state:
                    reward_down = self.hole_reward
                    term_down = True
                elif state_down == self.goal_state:
                    reward_down = self.goal_reward
                    term_down = True
                else:
                    reward_down = self.living_reward
                    term_down = False
                    
                if state_left == self.hole_state:
                    reward_left = self.hole_reward
                    term_left = True
                elif state_left == self.goal_state:
                    reward_left = self.goal_reward
                    term_left = True
                else:
                    reward_left = self.living_reward
                    term_left = False
                    
                if state_right == self.hole_state:
                    reward_right = self.hole_reward
                    term_right = True
                    
                elif state_right == self.goal_state:
                    reward_right = self.goal_reward
                    term_right = True
                else:
                    reward_right = self.living_reward
                    term_right = False

                #0 u, 1 d. 2 l, 3 r
                P[state][0] = [(0.8, state_up,reward_up,term_up), (0.1, state_left, reward_left, term_left), 
                                  (0.1, state_right, reward_right, term_right)]
                P[state][1] = [(0.8, state_down,reward_down,term_down), (0.1, state_left, reward_left, term_left), 
                                    (0.1, state_right, reward_right, term_right)]
                P[state][2] = [(0.8, state_left, reward_left, term_left), (0.1, state_up, reward_up, term_up),
                                    (0.1, state_down, reward_down, term_down)]
                P[state][3] = [(0.8, state_right, reward_right, term_right), (0.1, state_up, reward_up, term_up),
                                     (0.1, state_down, reward_down, term_down)]
                
            
        return P

    def _is_terminated(self, state):
        """
        Checks whether a given state is a terminal state.

        Args:
            state (int):
                The current state index of the agent.

        Returns:
            bool:
                True if the state corresponds to a goal or hole state,
                otherwise False.
        """
        if state == self.hole_state or state == self.goal_state:
            return True
        else:
            return False

    def _get_reward(self, state):
        """
        Computes the reward associated with a given state.

        Args:
            state (int):
                The state index reached after taking an action.

        Returns:
            float:
                Reward value for the given state. This may represent
                a goal reward, hole penalty, or living reward.
        """
        if state == self.hole_state:
            return self.hole_reward
        elif state == self.goal_state:
            return self.goal_reward
        else:
            return self.living_reward

    def _get_obs(self):
        """
        Generates the observation returned to the agent.

        Returns:
            dict:
                A dictionary containing:
                - agent: the agent's current state
                - terminals: list of terminal states
        """
        return {
            'agent': self.current_state, 
            'terminals': [self.hole_state, self.goal_state]
        }

    def _get_info(self):
        """
        Provides auxiliary diagnostic information.

        Returns:
            dict:
                A dictionary containing additional information such as
                the Manhattan distance between the agent and the goal state.
        """
        return self.info

    def reset(self, seed=None, options=None):
        """
        Resets the environment to its initial configuration.

        Args:
            seed (int or None):
                Random seed used to ensure reproducibility.
            options (dict or None):
                Additional reset options (if any).

        Returns:
            observation (dict):
                Initial observation of the environment.
            info (dict):
                Additional information after reset.
        """
        super().reset(seed=seed)
        if options is not None and 'max_steps' in options:
            self.max_steps = options['max_steps']
            
        self.current_state = self.start_state
        self.steps = 0
        self.info = {}
        return self._get_obs(), self._get_info()

    def step(self, action):
        """
        Executes one time step within the environment.

        Args:
            action (int):
                Action selected by the agent. Represents a movement
                direction in the maze.

        Returns:
            observation (dict):
                Observation after performing the action.
            reward (float):
                Reward received after the action.
            terminated (bool):
                Whether the episode has reached a terminal state.
            truncated (bool):
                Whether the episode was truncated due to time limits.
            info (dict):
                Additional diagnostic information including transition logs.
        """
        prev_state = self.current_state
        self.steps+=1
        trunc = False
        if self.max_steps is not None and self.steps >= self.max_steps:
            trunc = True
            
        transitions = self.P[prev_state][action]
        p = [t[0]  for t in transitions]
        selected = np.random.choice(len(transitions), p=p)
        
        self.current_state = transitions[selected][1]
        reward = transitions[selected][2]
        term = transitions[selected][3]
        
        return self._get_obs(), reward, term, trunc, self._get_info()

    def render(self):
        """
        Renders the current state of the environment.

        Returns:
            None
        """
        return None

    def _render_frame(self):
        """
        Renders a single frame of the environment for visualization.

        Returns:
            None
        """
        return None


    def close(self):
        """
        Cleans up environment resources.

        Returns:
            None
        """
        return None

# %%
register(
    id='aryan2579',
    entry_point='__main__:SlipperyMaze',
    max_episode_steps=None
)
# Out:
# /Users/aryanarora/Desktop/rl/drl/lib/python3.14/site-packages/gymnasium/envs/registration.py:636: UserWarning: WARN: Overriding environment aryan2579 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %% [markdown]
# # Define some utility function: You are free to use or not use them & define yours

# %% [markdown]
# ### Generate Trajectory based on Policy $\pi$ and return experience tuples $(s, a, r, s^{\prime})$

# %%
def generate_episode_trajectory(environment, Q, epsilon=None, config=None):
    """
    Generates a single episode trajectory by interacting with the environment
    using an epsilon-greedy policy derived from a given Q-function.

    Args:
        environment (gym.Env):
            The environment in which the agent operates. It must support
            reset() and step() methods and define a discrete action space.

        Q (numpy.ndarray):
            The action-value function (Q-table) of shape
            (number_of_states, number_of_actions). It is used to select
            greedy actions during exploitation.

        epsilon (float or None):
            Probability of selecting a random action instead of the greedy
            action. If None, the value is taken from the configuration.

        config (dict):
            Configuration dictionary containing episode-level parameters.
            This includes:
            - random seed
            - exploration rate
            - maximum number of steps per episode
            - environment-specific parameters

    Returns:
        list:
            A list of tuples representing the episode trajectory.
            Each tuple has the form:
            (current_state, action, reward, next_state)

            If the episode exceeds the maximum allowed number of steps,
            an empty list is returned.
    """
    
    seed = config['seed']
    max_steps = config['max_steps']
    if epsilon is None: 
        epsilon = config['epsilon']['initial_value']
    obs, info = environment.reset(seed=seed,options={'max_steps':max_steps})
    curr_state = obs['agent']
    term , trunc = False, False
    traj = []
    actions_size = Q.shape[1]
    while not term and not trunc: 
        x = np.random.uniform()
        if x>=epsilon: 
            action =  np.random.choice([a for a in range(actions_size) if Q[curr_state][a]== np.max(Q[curr_state])])
        else: 
            action = np.random.choice(range(actions_size))
        obs, reward, term, trunc, info = environment.step(action)
        next_state = obs['agent']
        traj.append((curr_state,action,reward,next_state))
        curr_state = next_state
        
    if term: 
        return traj
    return []

# %% [markdown]
# ### Decay $\alpha$

# %%
def decay_step_size(initial_value, final_value, episode, max_episode, decay_type, decay_stop=None):
    """
    Computes the step size (learning rate) for a given episode based on
    a specified decay strategy.

    Args:
        initial_value (float):
            Initial step size at the beginning of training.

        final_value (float):
            Final step size to which the learning rate decays.

        episode (int):
            Current episode index for which the step size is computed.

        max_episode (int):
            Total number of episodes over which decay is applied.

        decay_type (str):
            Type of decay strategy used for step size scheduling.
            Supported values include 'exponential' and 'linear'.

        decay_stop (int or None):
            Optional episode index after which the step size remains
            constant at the final value.

    Returns:
        float:
            Step size corresponding to the given episode based on the
            chosen decay strategy.
    """
    pass

# %% [markdown]
# **IMPLEMENTATION NOTE**
#   - Using linear space & geomspace for decaying alpha & epsilon

# %%
def generate_episode_step_sizes(initial_value, final_value, max_episode, decay_type, decay_stop=None):
    """
    Generates step sizes for all episodes using a specified decay strategy.

    Args:
        initial_value (float):
            Initial step size at the start of training.

        final_value (float):
            Final step size at the end of decay.

        max_episode (int):
            Total number of episodes for which step sizes are generated.

        decay_type (str):
            Decay strategy used to compute step sizes
            (e.g., 'exponential' or 'linear').

        decay_stop (int or None):
            Optional episode index after which the step size
            remains fixed.

    Returns:
        list:
            A list of step size values, where each entry corresponds
            to the step size for a particular episode.
    """
    decay_till = max_episode
    if decay_stop is not None: 
        decay_till = decay_stop
    
    if decay_type == 'linear':
        step_sizes = np.linspace(initial_value, final_value, num=decay_till)
    else: 
        step_sizes = np.geomspace(initial_value, final_value, num=decay_till)

    if decay_till<max_episode:
        step_sizes = np.append(step_sizes, np.full(max_episode - decay_till, final_value))
    return step_sizes

# %%
def plot_step_size_decay(step_sizes, max_steps, decay_type):
    """
    Visualizes the decay of step size across episodes.

    Args:
        step_sizes (list or numpy.ndarray):
            Sequence of step size values for each episode.

        max_steps (int):
            Number of episodes over which the step sizes are plotted.

        decay_type (str):
            Name of the decay strategy used, displayed in the plot title.

    Returns:
        None
    """
    plt.figure(figsize=(10,6))
    plt.plot(range(max_steps),step_sizes)
    plt.title(decay_type)
    plt.xlabel('episodes')
    plt.ylabel('step-size')
    plt.show()

# %%
CONFIG = {
    "seed": 101,
    'max_episodes': 1000,
    'discount_factor': 0.99,
    'max_steps': 500,
    'environment': {
        'total_states': 12,
        'maze_shape': (3, 4),
        'living_reward': -0.04,
        'total_actions': 4,
        'start_state': 8,
        'goal_state': 3,
        'hole_state': 7,
        'goal_reward': 1,
        'hole_reward': -1,
        'wall_state': 5,
    },
    'step_size': {
        'initial_value': 0.8,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': None
    },
    'epsilon': {
        'initial_value': 0.5,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': None
    }
}

# %% [markdown]
# ### Decay $\epsilon$

# %%
def decay_epsilon(initial_value, final_value, episode, max_episode, decay_type, decay_stop=None):
    """
    Computes the exploration rate (epsilon) for a given episode based on
    a specified decay strategy.

    Args:
        initial_value (float):
            Initial value of epsilon at the beginning of training.

        final_value (float):
            Minimum value of epsilon after decay.

        episode (int):
            Current episode index for which epsilon is computed.

        max_episode (int):
            Total number of episodes over which epsilon decay is applied.

        decay_type (str):
            Type of decay strategy used for epsilon scheduling.
            Supported values include 'exponential' and 'linear'.

        decay_stop (int or None):
            Optional episode index after which epsilon remains
            fixed at the final value.

    Returns:
        float:
            Epsilon value corresponding to the given episode based on
            the chosen decay strategy.
    """
    pass

# %%
def generate_episode_epsilons(initial_value, final_value, max_episode, decay_type, decay_stop=None):
    """
    Generates epsilon values for all episodes using a specified decay strategy.

    Args:
        initial_value (float):
            Initial epsilon value at the start of training.

        final_value (float):
            Final epsilon value after decay.

        max_episode (int):
            Total number of episodes for which epsilon values are generated.

        decay_type (str):
            Decay strategy used for computing epsilon values
            (e.g., 'linear' or 'exponential').

        decay_stop (int or None):
            Optional episode index after which epsilon remains constant.

    Returns:
        list:
            A list of epsilon values, where each element corresponds
            to the exploration rate for a particular episode.
    """
    decay_till = max_episode
    if decay_stop is not None: 
        decay_till = decay_stop
    
    if decay_type == 'linear':
        epsilons = np.linspace(initial_value, final_value, num=decay_till)
    else: 
        epsilons = np.geomspace(initial_value, final_value, num=decay_till)

    if decay_till<max_episode:
        epsilons = np.append(epsilons, np.full(max_episode - decay_till, final_value))
    
    return epsilons

# %%
def plot_epsilon_decay(epsilons, max_steps, decay_type):
    """
    Visualizes the decay of epsilon across training episodes.

    Args:
        step_sizes (list or numpy.ndarray):
            Sequence of epsilon values across episodes.

        max_steps (int):
            Number of episodes over which epsilon decay is plotted.

        decay_type (str):
            Name of the decay strategy used, displayed in the plot title.

    Returns:
        None
    """
    plt.figure(figsize=(10,6))
    plt.plot(range(max_steps),epsilons)
    plt.title(decay_type)
    plt.xlabel('episodes')
    plt.ylabel('epsilon')
    plt.show()

# %%
def get_policy_success(environment, policy, config=None):
    """
    Evaluates whether a given policy successfully reaches the goal state
    within a specified number of steps and computes the discounted return.

    Args:
        environment (gym.Env):
            The environment in which the policy is evaluated. It must
            support reset() and step() operations.

        policy (list or numpy.ndarray):
            A deterministic policy mapping each state to an action.
            The index represents the state and the value represents
            the action selected in that state.

        config (dict):
            Configuration dictionary containing evaluation parameters.
            This includes:
            - random seed
            - maximum number of steps
            - discount factor
            - environment-specific goal state information

    Returns:
        success (bool):
            True if the policy reaches the goal state within the allowed
            number of steps, otherwise False.

        return_reward (float):
            Discounted cumulative reward obtained while following
            the policy during the episode.
    """
    term, trunc = False, False
    total_rew = 0
    discount = config['discount_factor']
    max_steps = config['max_steps']
    obs, info = environment.reset(options = {'max_steps':max_steps})
    curr_state = obs['agent']
    goal_state = config['environment']['goal_state']
    f = 1 
    while not term and not trunc:
        action = policy[curr_state]
        obs, reward, term, trunc, info = environment.step(action)
        next_state = obs['agent']
        total_rew +=  (reward * f) 
        f *= discount
        curr_state = next_state

    if curr_state == goal_state:
        return True, total_rew
        
    return False, total_rew

# %%
def value_iteration(P, config, theta=1e-10):
    states = config['environment']['total_states']
    actions = config['environment']['total_actions']
    discount = config['discount_factor']
    wall_state = config['environment']['wall_state']
    
    V = np.zeros(states)
    
    while True:
        Q = np.zeros((states,actions))
        for state in range(states):
            if state == wall_state:
                continue
            for action in range(actions):
                for p, next_state, reward, done in P[state][action]:
                    if not done:
                        Q[state][action]+= p*(reward + discount*V[next_state])
                    else:
                        Q[state][action]+= p*reward
        if max(abs(V[state] - max(Q[state])) for state in range(states) if state!=wall_state) < theta:
            break
        V = np.max(Q,axis=1)
        policy = np.array([
            np.random.choice([a for a in range(actions) if Q[s][a] == np.max(Q[s])])
            for s in range(states)
        ])   
    return Q, V, policy

env = SlipperyMaze(config=CONFIG)

Q, V, Policy = value_iteration(env.P, CONFIG)
TRUE_VALUES = {
    'Q':Q,
    'V':V,
    'pi': Policy
}

# %%
def policy_rollout(environment, policy, rollouts, config):
    s_c, t_r = 0.0, 0.0
    for _ in range(rollouts):
        s, r = get_policy_success(environment, policy, config=config)
        if s:
            s_c +=1
        t_r+=r
        
    return ((s_c/rollouts) >= 0.5), (t_r/rollouts), (s_c/rollouts)

# %%
def plot_episode_values(V_r, image_name, TRUE_VALUES, config=None):
    """
    Visualizes the evolution of value estimates for non-terminal states
    across multiple episodes.

    Args:
        V_r (numpy.ndarray):
            A 2D array containing value estimates for each state
            across episodes. Each row corresponds to an episode,
            and each column corresponds to a state.

        image_name (str):
            Name of the output image file in which the plot
            will be saved.

        config (dict):
            Configuration dictionary containing experiment parameters.
            This includes:
            - total number of episodes
            - environment-specific state information
            - plotting-related settings

    Returns:
        None
    """
    plt.figure(figsize=(10,6))
    episodes, states = V_r.shape
    excluded = [config['environment']['wall_state'], config['environment']['goal_state'], config['environment']['hole_state']]
    for state in range(states):
        if state not in excluded:
            line, = plt.plot(np.arange(episodes), V_r[:,state], label = f" State: {state}")
            plt.axhline(y=TRUE_VALUES['V'][state], color=line.get_color(), linestyle='--', linewidth=1, label=f"True V (State: {state})")
            
    plt.xlabel('Episodes')
    plt.ylabel('Value Estimates')
    plt.title(image_name)
    plt.legend(loc='upper left', bbox_to_anchor=(1.01, 1), borderaxespad=0, framealpha=0.5)
    plt.savefig(f"{image_name}.svg", dpi=300, bbox_inches='tight')
    plt.show()

# %%
def plot_episode_q_values(Q_r, image_name, TRUE_VALUES, config=None):
    """
    Visualizes the evolution of action-value (Q) estimates for all actions
    and non-terminal states across multiple episodes.

    Args:
        Q_r (numpy.ndarray):
            A 3D array containing Q-value estimates.
            Dimensions correspond to:
            - episodes
            - states
            - actions

        image_name (str):
            Name of the output image file in which the plot
            will be saved.

        config (dict):
            Configuration dictionary containing experiment parameters.
            This includes:
            - number of episodes
            - total number of states
            - total number of actions
            - environment-specific terminal and wall states

    Returns:
        None
    """
    episodes, states, actions = Q_r.shape
    excluded = [config['environment']['wall_state'], config['environment']['goal_state'], config['environment']['hole_state']]
    colors = ['#e6194b', '#3cb44b', '#4363d8', '#f58231', '#911eb4', '#42d4f4', '#f032e6', '#bfef45', '#fabed4', '#469990', 
              '#9a6324', '#800000']

    fig, axes = plt.subplots(1, 4, figsize=(14, 4))
    action_label = ['up', 'down', 'left', 'right']
    for action in range(actions):
        ax = axes[action]
        for state in range(states):
            if state not in excluded:
                line, = ax.plot(np.arange(episodes), Q_r[:, state, action],
                                color=colors[state], label=f"State {state}")
                ax.axhline(y=TRUE_VALUES['Q'][state, action], color=colors[state],
                           linestyle='--', linewidth=1)
        ax.set_xlabel('Episodes')
        ax.set_ylabel('Q-Value Estimates')
        ax.set_title(f"Action: {action_label[action]}")

    handles, labels = axes[0].get_legend_handles_labels()
    dummy = plt.Line2D([0], [0], color='gray', linestyle='--', linewidth=1, label='True Value')
    handles.append(dummy)
    labels.append('True Value')

    fig.legend(handles=handles, labels=labels, loc='upper left',
               bbox_to_anchor=(1.01, 1), borderaxespad=0, framealpha=0.5)
    plt.tight_layout()
    plt.savefig(f"{image_name}.svg", dpi=300, bbox_inches='tight')
    plt.show()

# %%
def run_tests(n_tests=50, method=None, config=None):
    """
    Executes multiple independent experimental trials for a given
    reinforcement learning method and aggregates the results.

    Args:
        n_tests (int):
            Number of independent test runs to be performed. Each test
            uses a different random seed to evaluate robustness and
            stability of the learning method.

        method (callable):
            A reinforcement learning control method to be evaluated.
            This function is expected to take an environment and a
            configuration dictionary as input and return learned
            value functions, policies, and performance metrics.

        config (dict):
            Configuration dictionary containing experiment and
            environment parameters. This includes:
            - number of episodes
            - environment settings
            - learning hyperparameters
            - random seed information

    Returns:
        Qs (numpy.ndarray):
            A 4D array containing Q-value estimates for all tests,
            episodes, states, and actions.

        V_e (numpy.ndarray):
            A 3D array containing state-value estimates for all tests,
            episodes, and states.

        policy_success (numpy.ndarray):
            A 2D boolean array indicating whether the learned policy
            successfully reached the goal state in each episode
            across all tests.

        return_reward (numpy.ndarray):
            A 2D array containing the discounted return obtained
            in each episode across all test runs.
    """
    seed = config['seed']
    seeds = [seed + i for i in range(n_tests)]
    episodes = config['max_episodes']
    steps = config['max_steps']
    states = config['environment']['total_states']
    actions = config['environment']['total_actions']
    Qs = np.zeros((n_tests, episodes,states,actions))
    V_e = np.zeros((n_tests,episodes,states))
    policy_success = np.zeros((n_tests,episodes),dtype=bool)
    return_reward = np.zeros((n_tests,episodes))
    policy_success_rate = np.zeros((n_tests,episodes))

    for test in range(n_tests):
        temp_con = dict(config)
        temp_con['seed'] = seeds[test]
        np.random.seed(seeds[test])
        env = SlipperyMaze(config=temp_con)
        env.reset(seed=seeds[test], options={'max_steps': steps})
        a = method(env, config=temp_con)
        Qs[test] = a[3]
        V_e[test] = a[1]
        policy_success[test] = a[5]
        return_reward[test] = a[6]
        policy_success_rate[test] = a[7]

    return Qs, V_e, policy_success, return_reward, policy_success_rate

# %%
def action_select(state,Q,epsilon):
    select = np.random.uniform()
    if select>=epsilon: 
        action =  np.random.choice([a for a in range(Q.shape[1]) if Q[state][a]== np.max(Q[state])])
    else: 
        action = np.random.choice(range(Q.shape[1]))
    return action

# %%
def draw_maze(policy, config, title):

    ACTION_SYMBOLS = {0: '↑', 1: '↓', 2: '←', 3: '→'}
    rows = config['environment']['maze_shape'][0]
    cols = config['environment']['maze_shape'][1]
    wall  = config['environment']['wall_state']
    goal  = config['environment']['goal_state']
    hole  = config['environment']['hole_state']

    fig, ax = plt.subplots(figsize=(cols * 1.2, rows * 1.2))
    ax.set_xlim(0, cols)
    ax.set_ylim(0, rows)
    ax.set_aspect('equal')
    ax.axis('off')
    ax.set_title(title, fontsize=11)

    for s in range(rows * cols):
        r, c = s // cols, s % cols
        x, y = c, rows - 1 - r 
        ax.add_patch(plt.Rectangle((x, y), 1, 1, linewidth=1,
                                   edgecolor='black', facecolor='white'))

        cx, cy = x + 0.5, y + 0.5

        if s == wall:
            ax.text(cx, cy, f'{s} :W', ha='center', va='center', fontsize=14, fontweight='bold')
        elif s == goal:
            ax.text(cx, cy, f'{s} : G', ha='center', va='center', fontsize=14, fontweight='bold')
        elif s == hole:
            ax.text(cx, cy, f'{s} : H', ha='center', va='center', fontsize=14, fontweight='bold')
        else:
            symbol = ACTION_SYMBOLS.get(policy[s], '?')
            ax.text(cx, cy, f'{s} : {symbol}', ha='center', va='center', fontsize=16)

    plt.tight_layout()
    plt.savefig(f"{title}.svg", dpi=300)
    plt.show()

# %% [markdown]
# # Initialize parameters which can be useful later (Optional Here)

# %%
policy_success = np.zeros((4, 50, 1000))
return_reward = np.zeros((4,50,1000))
value_estimates = np.zeros((4,50,1000,12))

# %% [markdown]
# # Problem 1: Monte Carlo Control (40 points)
# ($40+20+20+5+5+5+5=100$ points)
#
# Implement the Monte Carlo Control for the Random Maze Environment (RME) described above. In particular, you need to implement First Visit Monte Carlo Control (FMVCC) for finding the optimal policy for
# RME. Use the function definition (given below) as given in Lecture slides.
# MonteCarloControl(env, $\gamma$, $\alpha_0$, $\epsilon_0$, maxSteps, noEpisodes, firstVisit = True)

# %%
def monte_carlo_control(environment, config=None):

    episodes = config['max_episodes']
    states = config['environment']['total_states']
    actions = config['environment']['total_actions']
    st_dic = config['step_size']
    ep_dic = config['epsilon']
    step_sizes = generate_episode_step_sizes(st_dic['initial_value'], st_dic['final_value'], episodes, 
                                             st_dic['decay_type'], st_dic['decay_stop'])
    epsilons = generate_episode_epsilons(ep_dic['initial_value'], ep_dic['final_value'], episodes, 
                                         ep_dic['decay_type'], ep_dic['decay_stop'])
    mc_type = config['monte_carlo_strategy']
    Q = np.zeros((states,actions))
    V_e = np.zeros((episodes,states))
    policy = np.array([-1]*states, dtype=int)
    Qs = np.zeros((episodes,states,actions))
    mc_target_tensor = np.zeros((states,actions))
    policy_success = np.zeros(episodes, dtype=bool)
    return_reward = np.zeros(episodes)
    discount = config['discount_factor']
    goal_state = config['environment']['goal_state']
    policy_success_rate = np.zeros(episodes)
    rollouts = config['rollouts']
    for e in range(episodes): 
        traj = generate_episode_trajectory(environment,Q,epsilons[e],config)
        if not traj:
            Qs[e] = Q.copy()
            V_e[e] = np.max(Q,axis=1)
            return_reward[e] = 0
            continue
        visited = np.zeros((states,actions), dtype=bool)
        for i,(curr_state,action,reward,next_state) in enumerate(traj):
            if visited[curr_state][action] and mc_type=='first_visit':
                continue
            visited[curr_state][action] = True
            target = sum((discount**(j-i))*traj[j][2] for j in range(i,len(traj)))
            mc_target_tensor[curr_state][action] = target
            Q[curr_state][action] +=  step_sizes[e]*(target - Q[curr_state][action])
    
        Qs[e] = Q.copy()
        V_e[e] = np.max(Q,axis=1)
        policy = np.array([
            np.random.choice([a for a in range(actions) if Q[s][a] == np.max(Q[s])])
            for s in range(states)
        ]) 
        
        policy_success[e], return_reward[e], policy_success_rate[e] = policy_rollout(environment, policy, rollouts, config)
        
    
    return Q, V_e, policy, Qs, mc_target_tensor, policy_success, return_reward, policy_success_rate

# %%
CONFIG = {
    "seed": 101,
    'max_episodes': 8000,
    'discount_factor': 0.99,
    'max_steps': 500,
    'rollouts': 20,
    'monte_carlo_strategy':'first_visit', 
    'environment': {
        'total_states': 12,
        'maze_shape': (3, 4),
        'living_reward': -0.04,
        'total_actions': 4,
        'start_state': 8,
        'goal_state': 3,
        'hole_state': 7,
        'goal_reward': 1,
        'hole_reward': -1,
        'wall_state': 5,
    },
    'step_size': {
        'initial_value': 0.4,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': 6000
    },
    'epsilon': {
        'initial_value': 0.8,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': 6000
    }
    
}



Q_mc, V_mc, policy_success_mc, return_reward_mc, policy_success_rate_mc = run_tests(n_tests=30,method=monte_carlo_control, config=CONFIG)
Q_avg_mc = np.mean(Q_mc, axis=0)
V_avg_mc = np.mean(V_mc, axis=0)
RR_avg_mc = np.mean(return_reward_mc, axis=0)
PSR_avg_mc = np.mean(policy_success_rate_mc, axis=0) * 100
policy_mc = np.argmax(Q_avg_mc[-1], axis=1)

# %% [markdown]
# ### (a) Plot State-value (20 points)
# Plot evolution of State-value (V) function with time. Basically, plot V-function vs Episodes for states 0,
# 1, 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true V-function for each of the state in the same plot.

# %%
plot_episode_values(V_avg_mc, 'mc-v-est', TRUE_VALUES, config=CONFIG )

# %% [markdown]
# (b) Plot Action state value (20 points)
# Plot evolution of action state value (Q) function with time. Plot Q function vs Episodes for states 0, 1,
# 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true Q-function for each of the state in the same plot.

# %%
plot_episode_q_values(Q_avg_mc, 'mc-q-est', TRUE_VALUES, config=CONFIG)

# %% [markdown]
# c) Instances and seeds (5 Points)
#  Describe over how many instances of the environments did you average the results? Write about the seeds used for each instance.

# %% [markdown]
# The results were averaged for 30 runs of the control method, i.e., 30 instances of the environment, each run had a unique seed, 'seed+run'.

# %% [markdown]
# (d) Environment diagram (5 points)
# Draw the environment diagram with optimal policy (shown using arrows) obtained using the algorithm.

# %%
draw_maze(policy_mc,CONFIG,'mc-diagram')

# %% [markdown]
# (e) Hyper-parameters (5 points)
# Write about the hyper-parameters you finally used for the algorithm and describe how did you arrive at these set of hyper-params.

# %% [markdown]
# To select the hyperparameters a grid-search was performed over step_size initial_value = (0.1, 0.4) X epsilon initial_value = (0.1, 0.8) X decay_stop= (4000,6000). The control algorithms were run over 5 instances, and relevant plots(Policy Success Rate, Value Estimates, Q-Value Estimates) were visualised and compared to reach at the final selected hyperparameters.
#
# - Step Size: Initial Value = 0.4, Final Value = 0.01, decay_type = 'exponential', decay_stop= 6000
# - Epsilon: Initial Value = 0.8, Final Value = 0.01, decay_type = 'exponential', decay_stop = 6000

# %% [markdown]
# (f) Observations (5 points)
# Write about your observations from the plots above.

# %% [markdown]
# - Value Estimation Plot:
#     - Except for states 9,10,11 all converge to their respective true values. Ordering of states is maintained.
#     - Due to the nature of Monte Carlo Control, initial estimates are highly variate.
#     - The convergence of states 9, 10, 11 to incorrect estimates can be attributed to the states being astray from the optimal path, therefore having less visits since we learn from a mostly Greedy Trajectory
#
#
# - Q-Value Estimation Plot:
#     - The hole penalty is overestimated for state 11 with action up, since this action is explored early but is not visited enough to correct the estimate toward the true value.
#     - True convergence to the optimal values is visible for action right in states 0, 1, 2 because these state–action pairs stay on the final greedy path and get frequently visited during training. Also for state 6, since action right leads to hole state.

# %% [markdown]
# # Problem 2: SARSA (TD Control)
# ($40+20+20+5+5+5+5=100$ points)
#
# Implement the SARSA algorithm for the Random Maze Environment (RME) described above. Use the function definition as given in Lecture slides.
# SARSA(env,$\gamma$, $\alpha_0$, $\epsilon_0$, noEpisodes)(40 Points)

# %%
def sarsa_control(environment, config=None):
    """
    Implements the SARSA (State–Action–Reward–State–Action) algorithm for a
    discrete Random Maze Environment (RME).

    This function applies the on-policy Temporal Difference (TD) control method
    SARSA to learn the optimal action-value function Q(s, a). An epsilon-greedy
    policy is used for both action selection and policy evaluation, with optional
    decay of the learning rate (alpha) and exploration rate (epsilon) across
    episodes.

    Args:
        environment (gym.Env): Environment with discrete observation and action spaces.
        config (dict): Configuration dictionary containing:
            - max_episodes (int): Number of training episodes.
            - discount_factor (float): Discount factor γ.
            - step_size (dict): Learning rate (alpha) decay parameters.
            - epsilon (dict): Epsilon-greedy exploration decay parameters.
            - seed (int): Random seed for environment reset.

    Returns:
        Q (np.ndarray): Final learned action-value function of shape (S, A).
        V_s (np.ndarray): State-value estimates derived from Q for each episode.
        policy (np.ndarray): Final greedy policy derived from Q.
        Qs (np.ndarray): History of Q-values across episodes.
        td_target (float): Last computed TD target value.
        policy_success (np.ndarray): Boolean success indicator per episode.
        return_reward (np.ndarray): Total return obtained per episode.
    """
    seed = config['seed']
    episodes = config['max_episodes']
    states = config['environment']['total_states']
    actions = config['environment']['total_actions']
    st_dic = config['step_size']
    ep_dic = config['epsilon']
    step_sizes = generate_episode_step_sizes(st_dic['initial_value'], st_dic['final_value'], episodes, 
                                             st_dic['decay_type'], st_dic['decay_stop'])
    epsilons = generate_episode_epsilons(ep_dic['initial_value'], ep_dic['final_value'], episodes, 
                                         ep_dic['decay_type'], ep_dic['decay_stop'])
    Q = np.zeros((states,actions))
    V_s = np.zeros((episodes,states))
    policy = np.array([-1]*states, dtype=int)
    Qs = np.zeros((episodes,states,actions))
    td_target = 0.0
    policy_success = np.zeros(episodes, dtype=bool)
    return_reward = np.zeros(episodes)
    discount = config['discount_factor']
    goal_state = config['environment']['goal_state']
    max_steps = config['max_steps']

    policy_success_rate = np.zeros(episodes)
    rollouts = config['rollouts']

    for e in range(episodes):
        obs, info = environment.reset(options={'max_steps': max_steps})
        state = obs['agent']
        term, trunc = False, False
        action = action_select(state,Q,epsilons[e])
        while not term and not trunc:
            obs, reward, term, trunc, info = environment.step(action)
            next_state = obs['agent']
            next_action = action_select(next_state,Q,epsilons[e])
            td_target = reward
            if not term: 
                td_target+= discount * Q[next_state][next_action]
            td_error = td_target - Q[state][action]
            Q[state][action] += (step_sizes[e]*td_error)
            state = next_state
            action = next_action

        
        Qs[e] = Q.copy()
        V_s[e] = np.max(Q,axis=1)
        policy = np.array([
            np.random.choice([a for a in range(actions) if Q[s][a] == np.max(Q[s])])
            for s in range(states)
        ]) 
        policy_success[e], return_reward[e], policy_success_rate[e] = policy_rollout(environment, policy, rollouts, config)
    return Q, V_s, policy, Qs, td_target, policy_success, return_reward, policy_success_rate

# %%
CONFIG = {
    "seed": 101,
    'max_episodes': 8000,
    'discount_factor': 0.99,
    'max_steps': 500,
    'rollouts': 20, 
    'environment': {
        'total_states': 12,
        'maze_shape': (3, 4),
        'living_reward': -0.04,
        'total_actions': 4,
        'start_state': 8,
        'goal_state': 3,
        'hole_state': 7,
        'goal_reward': 1,
        'hole_reward': -1,
        'wall_state': 5,
    },
    'step_size': {
        'initial_value': 0.4,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': 6000
    },
    'epsilon': {
        'initial_value': 0.8,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': 6000
    }
    
}
Q_td, V_td, policy_success_td, return_reward_td, policy_success_rate_td = run_tests(n_tests=30,method=sarsa_control, config=CONFIG)
Q_avg_td = np.mean(Q_td, axis=0)
V_avg_td = np.mean(V_td, axis=0)
RR_avg_td = np.mean(return_reward_td, axis=0)
PSR_avg_td = np.mean(policy_success_rate_td, axis=0) * 100
policy_td = np.argmax(Q_avg_td[-1], axis=1)

# %% [markdown]
# (a) State-value function (20 Points)
# Plot evolution of State-value (V) function with time. Basically, plot V-function vs Episodes for states 0,
# 1, 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true V-function for each of the state in the same plot.

# %%
plot_episode_values(V_avg_td, 'sarsa-v-est', TRUE_VALUES, config=CONFIG)

# %% [markdown]
# (b) Action state value (Q) function (20 Points)
# Plot evolution of action state value (Q) function with time. Plot Q function vs Episodes for states 0, 1,
# 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true Q-function for each of the state in the same plot.

# %%
plot_episode_q_values(Q_avg_td, 'sarsa-q-est', TRUE_VALUES, config=CONFIG)

# %% [markdown]
# (c) Instances and seeds (5 Points)
# Describe over how many instances of the environments did you average the results? Write about the seeds used for each instance.

# %% [markdown]
# The results were averaged for 30 runs of the control method, i.e., 30 instances of the environment, each run had a unique seed, 'seed+run'.

# %% [markdown]
# d) Environment diagram (5 Points)
# Draw the environment diagram with optimal policy (shown using arrows) obtained using the algorithm.

# %%
draw_maze(policy_td,CONFIG,'sarsa-diagram')

# %% [markdown]
# (e) Hyper-parameters (5 Points)
# Write about the hyper-parameters you finally used for the algorithm and describe how did you arrive at these set of hyper-params.

# %% [markdown]
# To select the hyperparameters a grid-search was performed over step_size initial_value = (0.1, 0.4) X epsilon initial_value = (0.1, 0.8) X decay_stop= (4000,6000). The control algorithms were run over 5 instances, and relevant plots(Policy Success Rate, Value Estimates, Q-Value Estimates) were visualised and compared to reach at the final selected hyperparameters.
#
# - Step Size: Initial Value = 0.4, Final Value = 0.01, decay_type = 'exponential', decay_stop= 6000
# - Epsilon: Initial Value = 0.8, Final Value = 0.01, decay_type = 'exponential', decay_stop = 6000

# %% [markdown]
# (f) Observations (5 Points)
# Write about your observations from the plots above.

# %% [markdown]
# - Value Estimation Plot:
#     - Except for states 9,10 all converge to their respective true values. Ordering of states is maintained.
#     - Due to the nature of SARSA Control(boot strapping), initial estimates are highly biased.
#     - The convergence of states 9, 10 to incorrect estimates can be attributed to the states being astray from the optimal path, therefore having less visits since we derive a Greedy Policy.
#     - It is important to note that state 6, although oscillating with a very small amptitude below it's true value, has not yet fully plateaued. This is because of the stochasticity and 1 step bootstrapping as state 6 might lead to Hole State or One state away from Goal State( state - 2).
#
#
# - Q-Value Estimation Plot:
#     - The states near the hole state are penalised heavily(more than monte carlo) across actions, except for state,action 6,up. The states on the optimal path are assigned values higher than monte carlo estimates although lower than their true values. This shows the biased nature of SARSA Algorithm

# %% [markdown]
# # Problem 3: Q-Learning
# ($40+20+20+5+5+5+5=100$ points)
#
# Implement the Q-Learning algorithm for the Random Maze Environment (RME) described above. Use the function definition as given in Lecture slides.
# Q-Learning(env, $\gamma$, $\alpha_0$, $\epsilon_0$, noEpisodes) (40 Points)

# %%
def q_learning_control(environment, config=None):
    """
    Implements the Q-Learning algorithm for a discrete Random Maze Environment (RME).

    This function applies Q-Learning, an off-policy Temporal Difference (TD) control
    algorithm, to learn the optimal action-value function Q(s, a). Action selection
    is performed using an epsilon-greedy behavior policy, while updates are based on
    the greedy target policy. Learning rate (alpha) and exploration rate (epsilon)
    may decay across episodes.

    Args:
        environment (gym.Env): Environment with discrete observation and action spaces.
        config (dict): Configuration dictionary containing:
            - max_episodes (int): Number of training episodes.
            - discount_factor (float): Discount factor γ.
            - step_size (dict): Learning rate (alpha) decay parameters.
            - epsilon (dict): Epsilon-greedy exploration decay parameters.
            - seed (int): Random seed for environment reset.

    Returns:
        Q (np.ndarray): Final learned action-value function of shape (S, A).
        V_s (np.ndarray): State-value estimates derived from Q for each episode.
        policy (np.ndarray): Final greedy policy derived from Q.
        Qs (np.ndarray): History of Q-values across episodes.
        None: Placeholder (no TD target history stored).
        policy_success (np.ndarray): Boolean success indicator per episode.
        return_reward (np.ndarray): Total return obtained per episode.
    """


    seed = config['seed']
    episodes = config['max_episodes']
    states = config['environment']['total_states']
    actions = config['environment']['total_actions']
    st_dic = config['step_size']
    ep_dic = config['epsilon']
    step_sizes = generate_episode_step_sizes(st_dic['initial_value'], st_dic['final_value'], episodes, 
                                             st_dic['decay_type'], st_dic['decay_stop'])
    epsilons = generate_episode_epsilons(ep_dic['initial_value'], ep_dic['final_value'], episodes, 
                                         ep_dic['decay_type'], ep_dic['decay_stop'])
    Q = np.zeros((states,actions))
    V_s = np.zeros((episodes,states))
    policy = np.array([-1]*states, dtype=int)
    Qs = np.zeros((episodes,states,actions))
    policy_success = np.zeros(episodes, dtype=bool)
    return_reward = np.zeros(episodes)
    discount = config['discount_factor']
    goal_state = config['environment']['goal_state']
    max_steps = config['max_steps']
    policy_success_rate = np.zeros(episodes)
    rollouts = config['rollouts']

    for e in range(episodes):
        obs, info = environment.reset(options={'max_steps': max_steps})
        state = obs['agent']
        term, trunc = False, False
        while not term and not trunc:
            action = action_select(state,Q,epsilons[e])
            obs, reward, term, trunc, info = environment.step(action)
            next_state = obs['agent']
            td_target = reward
            if not term: 
                td_target+= discount * np.max(Q[next_state])
            td_error = td_target - Q[state][action]
            Q[state][action] += (step_sizes[e]*td_error)
            state = next_state
            
        
        Qs[e] = Q.copy()
        V_s[e] = np.max(Q,axis=1)
        policy = np.array([
            np.random.choice([a for a in range(actions) if Q[s][a] == np.max(Q[s])])
            for s in range(states)
        ]) 
        policy_success[e], return_reward[e], policy_success_rate[e] = policy_rollout(environment, policy, rollouts, config)

    return Q, V_s, policy, Qs, None, policy_success, return_reward, policy_success_rate

# %%
CONFIG = {
    "seed": 101,
    'max_episodes': 8000,
    'discount_factor': 0.99,
    'max_steps': 500,
    'rollouts': 20,
    'planning': 25, 
    'lambda':0.5,
    'monte_carlo_strategy':'first_visit', 
    'replace_trace': True, 
    'environment': {
        'total_states': 12,
        'maze_shape': (3, 4),
        'living_reward': -0.04,
        'total_actions': 4,
        'start_state': 8,
        'goal_state': 3,
        'hole_state': 7,
        'goal_reward': 1,
        'hole_reward': -1,
        'wall_state': 5,
    },
    'step_size': {
        'initial_value': 0.4,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': 4000
    },
    'epsilon': {
        'initial_value': 0.8,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': 4000
    }
    
}

Q_q, V_q, policy_success_q, return_reward_q, policy_success_rate_q = run_tests(n_tests=30,method=q_learning_control, config=CONFIG)
Q_avg_q = np.mean(Q_q, axis=0)
V_avg_q = np.mean(V_q, axis=0)
RR_avg_q = np.mean(return_reward_q, axis=0)
PSR_avg_q = np.mean(policy_success_rate_q, axis=0) * 100
policy_q = np.argmax(Q_avg_q[-1], axis=1)

# %% [markdown]
# (a) State-value (V) function (20 Points)
# Plot evolution of State-value (V) function with time. Basically, plot V-function vs Episodes for states 0,
# 1, 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true V-function for each of the state in the same plot.

# %%
plot_episode_values(V_avg_q,'q-v-est', TRUE_VALUES, CONFIG)

# %% [markdown]
# (b)Action state value (Q) function (20 Points)
# Plot evolution of action state value (Q) function with time. Plot Q function vs Episodes for states 0, 1,
# 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true Q-function for each of the state in the same plot.

# %%
plot_episode_q_values(Q_avg_q, 'q-q-est', TRUE_VALUES,CONFIG)

# %% [markdown]
# (c) Instances and seeds (5 Points)
# Describe over how many instances of the environments did you average the results? Write about the seeds used for each instance.

# %% [markdown]
# The results were averaged for 30 runs of the control method, i.e., 30 instances of the environment, each run had a unique seed, 'seed+run'.

# %% [markdown]
# (d) Environment diagram (5 Points)
# Draw the environment diagram with optimal policy (shown using arrows) obtained using the algorithm.

# %%
draw_maze(policy_q, CONFIG, 'q-diagram')

# %% [markdown]
# (e) hyper-parameters (5 Points)
# Write about the hyper-parameters you finally used for the algorithm and describe how did you arrive at
# these set of hyper-params.

# %% [markdown]
# To select the hyperparameters a grid-search was performed over step_size initial_value = (0.1, 0.4) X epsilon initial_value = (0.1, 0.8) X decay_stop= (4000,6000). The control algorithms were run over 5 instances, and relevant plots(Policy Success Rate, Value Estimates, Q-Value Estimates) were visualised and compared to reach at the final selected hyperparameters.
#
# - Step Size: Initial Value = 0.4, Final Value = 0.01, decay_type = 'exponential', decay_stop= 4000
# - Epsilon: Initial Value = 0.8, Final Value = 0.01, decay_type = 'exponential', decay_stop = 4000

# %% [markdown]
# (f) Observations (5 Points)
# Write about your observations from the plots above.

# %% [markdown]
# - Value Estimation Plot:
#     - Convergance to true values is cleaner and faster (due to bootstrapping with the max next_action). Making it more sample efficient as compared to SARSA and Monte Carlo
#     - Unlike SARSA which had an underestimation bias, the values initially overshoot due to max next_action bootstrapping update.
#
#
# - Q-Value Estimation Plot:
#     - The Q estimates converge close to the true values with negligible bias for most states and actions, except state 6 which is clearly sensitive. For state 6, only the optimal policy action (up) and worst action(right) are correcly estimated, while the other actions for state 6 are strongly underestimated.
#     - The action chosen by the greedy policy for state 11 is down, optimising for -0.04 over -1, as down from 11 can never lead to hole state.

# %% [markdown]
# # **Problem 4: Double Q-Learning**
#
# ($40+20+20+5+5+5+5=100$ points)
#
# Implement the Double Q-Learning algorithm for the Random Maze Environment (RME) described above.
# Use the function definition as given in Lecture slides.
#
# Double-Q-Learning(env, $\gamma$, $\alpha_0$, $\epsilon_0$, noEpisodes) (40 Points)

# %%
def double_q_learning_control(environment, config=None):
    """
    Implements the Double Q-Learning algorithm for a discrete Random Maze
    Environment (RME).

    This function applies Double Q-Learning, an off-policy Temporal Difference
    (TD) control algorithm designed to reduce maximization bias present in
    standard Q-Learning. Two independent action-value functions (Q1 and Q2)
    are learned by alternating updates, while action selection is performed
    using an epsilon-greedy policy derived from their average.

    Args:
        environment (gym.Env): Environment with discrete observation and action spaces.
        config (dict): Configuration dictionary containing:
            - max_episodes (int): Number of training episodes.
            - discount_factor (float): Discount factor γ.
            - step_size (dict): Learning rate (alpha) decay parameters.
            - epsilon (dict): Epsilon-greedy exploration decay parameters.
            - seed (int): Random seed for environment reset.

    Returns:
        Q (np.ndarray): Final combined action-value function (average of Q1 and Q2).
        V_s (np.ndarray): State-value estimates derived from Q for each episode.
        policy (np.ndarray): Final greedy policy derived from Q.
        Qs (np.ndarray): History of combined Q-values across episodes.
        None: Placeholder (no TD target history stored).
        policy_success (np.ndarray): Boolean success indicator per episode.
        return_reward (np.ndarray): Total return obtained per episode.
    """

    seed = config['seed']
    episodes = config['max_episodes']
    states = config['environment']['total_states']
    actions = config['environment']['total_actions']
    st_dic = config['step_size']
    ep_dic = config['epsilon']
    step_sizes = generate_episode_step_sizes(st_dic['initial_value'], st_dic['final_value'], episodes, 
                                             st_dic['decay_type'], st_dic['decay_stop'])
    epsilons = generate_episode_epsilons(ep_dic['initial_value'], ep_dic['final_value'], episodes, 
                                         ep_dic['decay_type'], ep_dic['decay_stop'])
    Q = np.zeros((states,actions))
    Q1 = np.zeros((states,actions))
    Q2 = np.zeros((states,actions))
    V_s = np.zeros((episodes,states))
    policy = np.array([-1]*states, dtype=int)
    Qs = np.zeros((episodes,states,actions))
    policy_success = np.zeros(episodes, dtype=bool)
    return_reward = np.zeros(episodes)
    discount = config['discount_factor']
    goal_state = config['environment']['goal_state']
    max_steps = config['max_steps']
    policy_success_rate =np.zeros(episodes)
    rollouts = config['rollouts']
    for e in range(episodes):
        obs, info = environment.reset(options={'max_steps': max_steps})
        state = obs['agent']
        term, trunc = False, False
        while not term and not trunc:
            action = action_select(state,Q,epsilons[e])
            obs, reward, term, trunc, info = environment.step(action)
            next_state = obs['agent']
            td_target = reward

            if np.random.randint(2):
                a1 = np.argmax(Q1[next_state])
                if not term:
                    td_target += discount*(Q2[next_state][a1])
                td_error = td_target - Q1[state][action]
                Q1[state][action] +=  (step_sizes[e]*td_error)
            else:
                a2 = np.argmax(Q2[next_state])
                if not term:
                    td_target+= discount*(Q1[next_state][a2])
                td_error = td_target - Q2[state][action]
                Q2[state][action] += (step_sizes[e]*td_error)
            state = next_state
        

        Q = (Q1+Q2)/2
        Qs[e] = Q.copy()
        V_s[e] = np.max(Q,axis=1)
        policy = np.array([
            np.random.choice([a for a in range(actions) if Q[s][a] == np.max(Q[s])])
            for s in range(states)
        ]) 
        policy_success[e], return_reward[e], policy_success_rate[e] = policy_rollout(environment, policy, rollouts, config)

    return Q, V_s, policy, Qs, None, policy_success, return_reward, policy_success_rate

# %%
CONFIG = {
    "seed": 101,
    'max_episodes': 8000,
    'discount_factor': 0.99,
    'max_steps': 500,
    'rollouts': 20,
    'environment': {
        'total_states': 12,
        'maze_shape': (3, 4),
        'living_reward': -0.04,
        'total_actions': 4,
        'start_state': 8,
        'goal_state': 3,
        'hole_state': 7,
        'goal_reward': 1,
        'hole_reward': -1,
        'wall_state': 5,
    },
    'step_size': {
        'initial_value': 0.4,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': 4000
    },
    'epsilon': {
        'initial_value': 0.8,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': 4000
    }
    
}

Q_dq, V_dq, policy_success_dq, return_reward_dq, policy_success_rate_dq = run_tests(n_tests=30,method=double_q_learning_control, config=CONFIG)
Q_avg_dq = np.mean(Q_dq, axis=0)
V_avg_dq = np.mean(V_dq, axis=0)
RR_avg_dq = np.mean(return_reward_dq, axis=0)
PSR_avg_dq = np.mean(policy_success_rate_dq, axis=0) * 100
policy_dq = np.argmax(Q_avg_dq[-1], axis=1)

# %% [markdown]
# (a) State-value (V) function (20 Points)
# Plot evolution of State-value (V) function with time. Basically, plot V-function vs Episodes for states 0,
# 1, 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true V-function for each of the state in the same plot.

# %%
plot_episode_values(V_avg_dq, 'dq-v-est', TRUE_VALUES, CONFIG)

# %% [markdown]
# (b) Action state value (Q) function (20 Points)
# Plot evolution of action state value (Q) function with time. Plot Q function vs Episodes for states 0, 1,
# 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true Q-function for each of the state in the same plot.

# %%
plot_episode_q_values(Q_avg_dq, 'dq-q-est', TRUE_VALUES, CONFIG)

# %% [markdown]
# (c) Instances and seeds (5 Points)
# Describe over how many instances of the environments did you average the results? Write about the seeds
# used for each instance.

# %% [markdown]
# The results were averaged for 30 runs of the control method, i.e., 30 instances of the environment, each run had a unique seed, 'seed+run'.

# %% [markdown]
# (d) Environment diagram (5 Points)
# Draw the environment diagram with optimal policy (shown using arrows) obtained using the algorithm.

# %%
draw_maze(policy_dq, CONFIG, 'dq-diagram')

# %% [markdown]
# (e) hyper-parameters (5 Points)
# Write about the hyper-parameters you finally used for the algorithm and describe how did you arrive at
# these set of hyper-params.

# %% [markdown]
# To select the hyperparameters a grid-search was performed over step_size initial_value = (0.1, 0.4) X epsilon final_value = (0.01, 0.05) X decay_stop= (4000,6000). The control algorithms were run over 5 instances, and relevant plots(Policy Success Rate, Value Estimates, Q-Value Estimates) were visualised and compared to reach at the final selected hyperparameters.
#
# - Step Size: Initial Value = 0.4, Final Value = 0.01, decay_type = 'exponential', decay_stop= 4000
# - Epsilon: Initial Value = 0.8, Final Value = 0.01, decay_type = 'exponential', decay_stop = 4000

# %% [markdown]
# (f) Observations (5 Points)
# Write about your observations from the plots above.

# %% [markdown]
# - Value Estimation Plot:
#     - Convergance to true values remains clear and fast.
#     - Due to the nature of 'DOUBLE' Q learning, the overshooting of value estimates initially has significantly reduced(compared to Q learning, as it avoids the Maximisation Bias Problem).
#     - Out of all 4 control algorithms, the 6th state(between hole and wall, and two steps away from goal) converges for Double Q learning, as it avoids the Maximisation Bias Problem.
#
#
# - Q-Value Estimation Plot:
#     - The Q estimates converge close to the true values with negligible bias for most states and actions, except for states closer to the hole state, for which, there is clear underestimation, even for optimal actions. This is unlike Q-learning. Since Double Q-learning doesn't exploit as much as Q-learning, for states with high risk of reaching hole, the values for optimal actions get underestimated.

# %% [markdown]
# # **Problem 5: Comparing Control Algorithms**
# ($20+5+5+5+5+5=40$ points)
#
# For FVMCC, SARSA, Q and Double-Q algorithms implemented above, do the following:

# %% [markdown]
# **Implementation Note**
# - instead of getPolicySuccessRate, I have utilised a self defined function - policy_rollout, which internally calls the previously created getPolicySuccess. Based on the clarifications by a TA, I have calculated the mean policy success rate across rollouts at every episode and then computed mean across runs for different instances. Same with return reward

# %%
policy_success_rate = np.stack((PSR_avg_mc, PSR_avg_td, PSR_avg_q, PSR_avg_dq), axis=0)
return_reward = np.stack((RR_avg_mc, RR_avg_td, RR_avg_q, RR_avg_dq), axis=0)
state_values = np.stack((V_avg_mc, V_avg_td, V_avg_q, V_avg_dq), axis=0)

# %% [markdown]
# a)Policy Success Rate (in %) vs Episodes (20 Points)
# For each of the algorithm, in a single plot, plot the evolution of Policy Success Rate (in %) vs Episodes.
# Policy Success Rate is defined as number of times the agent reaches the goal state out of the total number
# of the episodes run using a specific policy. Basically implement the following function that would return
# the policy success percentage. As you are training the agent, at each episode, you will have a version of
# the policy, use that policy along with the function below to get the policy success rate.
#
# def getPolicySuccessRate(env, $π_\text{current}$, goalState, maxEpisodes=100, maxSteps=200)

# %%
def plot_policy_success(policy_success, title, image_name, config=None):
    plt.plot(figsize=(10,6))
    episodes = np.arange(policy_success.shape[1])
    colors = ['#f54842', '#d4f542', '#1fcc5e', '#0b177d']
    labels = ['MONTE-CARLO', 'SARSA', 'Q-LEARNING', 'DOUBLE Q-LEARNING']
    for i in range(4):
        plt.plot(episodes, policy_success[i], color=colors[i], label=labels[i], linewidth=0.4)
    plt.xlabel('episodes')
    plt.ylabel('policy success rate')
    plt.title(title)
    plt.legend(loc='upper left', bbox_to_anchor=(1.01, 1), borderaxespad=0, framealpha=0.9)
    plt.savefig(f"{image_name}.svg", dpi=300, bbox_inches='tight')
    plt.show()
    
plot_policy_success(policy_success_rate, 'POLICY SUCCESS RATE for different CONTROL Algos', 'PSR-1')

# %% [markdown]
# (b)Policy Success Rate (in %) plot (5 Points)
# What are your observations from the Policy Success Rate (in %) plot.

# %% [markdown]
# - Q learning and Double Q learning reach high success rate quicker than others, thus making them the most sample efficient.
# - SARSA, although less sample efficient than Q and Double Q-Learning, is much faster and more sample efficient than Monte Carlo Control
# - The faster learning can be attributed to the off policy nature of Q and Double Q learning.

# %% [markdown]
# c) Estimated Expected Return (5 Points)
# For each of the algorithm (in a single plot), plot the Estimated Expected Return (from the start state) vs
# Episodes.

# %%
def plot_expected_return(return_reward, title, image_name, config=None):
    plt.plot(figsize=(10,6))
    episodes = np.arange(return_reward.shape[1])
    colors = ['#f54842', '#d4f542', '#1fcc5e', '#0b177d']
    labels = ['MONTE-CARLO', 'SARSA', 'Q-LEARNING', 'DOUBLE Q-LEARNING']
    for i in range(4):
        plt.plot(episodes, return_reward[i], color=colors[i], label=labels[i], linewidth=0.5)
    plt.xlabel('episodes')
    plt.ylabel('return reward')
    plt.title(title)
    plt.legend(loc='upper left', bbox_to_anchor=(1.01, 1), borderaxespad=0, framealpha=0.5)
    plt.savefig(f"{image_name}.svg", dpi=300, bbox_inches='tight')
    plt.show()

plot_expected_return(return_reward, 'EXPECTED RETURN for different CONTROL Algos', 'ER-1')

# %% [markdown]
# d) observations (5 Points)
# What are your observations for the Estimated Expected Return plot?

# %% [markdown]
# - Q learning and Double Q learning reach high expected return quicker than others, and are the first ones to converge.
# - SARSA, although converges slower than Q and Double Q-Learning, outperforms Monte Carlo Control.
# - It is important to note that the expected return here for an episode is the mean of returns recieved by following policy p derived at episode e. Thus supporting our previous claim of Q and Double Q learning being more sample efficient than others as they estimate the optimal policy quickly.

# %% [markdown]
# e)State-value Function Estimation Error vs Episodes (5 Points)
#
# For each of the algorithm (in a single plot), plot the State-value Function Estimation Error vs Episodes.
# State-value Function Estimation Error is defined as Mean Absolute Error across all V-function estimates
# (across all states) from the respective optimal value.

# %%
def plot_state_value_error(state_values, title, image_name, TRUE_VALUES, config=None):
    sv_error = np.mean(np.abs(state_values - TRUE_VALUES['V'][None, None, :]), axis=2)
    plt.plot(figsize=(10,6))
    episodes = np.arange(state_values.shape[1])
    colors = ['#f54842', '#d4f542', '#1fcc5e', '#0b177d']
    labels = ['MONTE-CARLO', 'SARSA', 'Q-LEARNING', 'DOUBLE Q-LEARNING']
    for i in range(4):
        plt.plot(episodes, sv_error[i], color=colors[i], label=labels[i], linewidth=0.5)
    plt.xlabel('episodes')
    plt.ylabel('state value error')
    plt.title(title)
    plt.legend(loc='upper left', bbox_to_anchor=(1.01, 1), borderaxespad=0, framealpha=0.5)
    plt.savefig(f"{image_name}.svg", dpi=300, bbox_inches='tight')
    plt.show()
    
plot_state_value_error(state_values,'STATE VALUE ESTIMATION ERROR for different CONTROL Algos', 'SVE-1', TRUE_VALUES)

# %% [markdown]
# f)observations for the State-value Function Estimation Error plot (5 Points)
# What are your observations for the State-value Function Estimation Error plot? (5 Points)

# %% [markdown]
# - The state value estimation error has a sharp drop for Q learning and Double Q learning, attributed, again, to the sample efficiency of these control algorithms.
# - SARSA On the other hand has a less variate error than Monte Carlo, and stabilises before it as well.
# - It is important to note the significant difference between estimation error even after 8000 episodes. Making Q and Double Q learning the clear choice for this problem.

# %% [markdown]
# # **Problem 6: SARSA($\lambda$) Replacing**
# (40+20+20+5+5+5+5=100 points)
#
# Implement the SARSA(λ) algorithm with Replacing Eligibility Traces for the Random Maze Environment
# (RME) described above. Use the function definition as given in Lecture slides.
#
# SARSA-Lambda(env, γ, α0, ϵ0, λ, noEpisodes, replaceTrace = True)
# (40 Points)

# %%
def sarsa_lambda_control(environment, config=None):
    """
    Implements the SARSA(λ) algorithm with eligibility traces for a discrete
    Random Maze Environment (RME).

    This function applies SARSA(λ), an on-policy Temporal Difference (TD) control
    algorithm that extends SARSA by incorporating eligibility traces to speed up
    learning. Eligibility traces allow credit assignment to multiple previously
    visited state-action pairs. Both accumulating and replacing traces are
    supported, as specified in the configuration.

    Args:
        environment (gym.Env): Environment with discrete observation and action spaces.
        config (dict): Configuration dictionary containing:
            - max_episodes (int): Number of training episodes.
            - discount_factor (float): Discount factor γ.
            - lambda (float): Eligibility trace decay parameter λ.
            - trace (str): Type of eligibility trace ('accumulating' or 'replacing').
            - step_size (dict): Learning rate (alpha) decay parameters.
            - epsilon (dict): Epsilon-greedy exploration decay parameters.
            - seed (int): Random seed for environment reset.

    Returns:
        Q (np.ndarray): Final learned action-value function of shape (S, A).
        V_s (np.ndarray): State-value estimates derived from Q for each episode.
        policy (np.ndarray): Final greedy policy derived from Q.
        Qs (np.ndarray): History of Q-values across episodes.
        td_target (float): Last computed TD target value.
        policy_success (np.ndarray): Boolean success indicator per episode.
        return_reward (np.ndarray): Total return obtained per episode.
    """


    episodes = config['max_episodes']
    states = config['environment']['total_states']
    actions = config['environment']['total_actions']
    st_dic = config['step_size']
    ep_dic = config['epsilon']
    step_sizes = generate_episode_step_sizes(st_dic['initial_value'], st_dic['final_value'], episodes, 
                                             st_dic['decay_type'], st_dic['decay_stop'])
    epsilons = generate_episode_epsilons(ep_dic['initial_value'], ep_dic['final_value'], episodes, 
                                         ep_dic['decay_type'], ep_dic['decay_stop'])
    Q = np.zeros((states,actions))
    V_s = np.zeros((episodes,states))
    policy = np.array([-1]*states, dtype=int)
    Qs = np.zeros((episodes,states,actions))
    td_target = 0.0
    policy_success = np.zeros(episodes, dtype=bool)
    return_reward = np.zeros(episodes)
    discount = config['discount_factor']
    goal_state = config['environment']['goal_state']
    max_steps = config['max_steps']
    replaceTrace = config['replace_trace']
    l = config['lambda']
    policy_success_rate = np.zeros(episodes)
    rollouts = config['rollouts']
    
    for e in range(episodes):
        E = np.zeros((states,actions))
        obs, info = environment.reset(options={'max_steps': max_steps})
        state = obs['agent']
        term, trunc = False, False
        action = action_select(state,Q,epsilons[e])
        while not term and not trunc:
            obs, reward, term, trunc, info = environment.step(action)
            next_state = obs['agent']
            next_action = action_select(next_state,Q,epsilons[e])
            td_target = reward
            if not term: 
                td_target+= discount * Q[next_state][next_action]
            td_error = td_target - Q[state][action]
            E[state][action]+=1
            if replaceTrace:
                E  = np.clip(E,0,1)
            Q += (step_sizes[e]*td_error*E)
            E*=discount*l
            state = next_state
            action = next_action

        
        Qs[e] = Q.copy()
        V_s[e] = np.max(Q,axis=1)
        policy = np.array([
            np.random.choice([a for a in range(actions) if Q[s][a] == np.max(Q[s])])
            for s in range(states)
        ]) 
        policy_success[e], return_reward[e], policy_success_rate[e] = policy_rollout(environment, policy, rollouts, config)
    return Q, V_s, policy, Qs, td_target, policy_success, return_reward, policy_success_rate

# %%
CONFIG = {
    "seed": 101,
    'max_episodes': 8000,
    'discount_factor': 0.99,
    'max_steps': 500,
    'rollouts': 20,
    'lambda':0.7,
    'replace_trace': True, 
    'environment': {
        'total_states': 12,
        'maze_shape': (3, 4),
        'living_reward': -0.04,
        'total_actions': 4,
        'start_state': 8,
        'goal_state': 3,
        'hole_state': 7,
        'goal_reward': 1,
        'hole_reward': -1,
        'wall_state': 5,
    },
    'step_size': {
        'initial_value': 0.1,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': None
    },
    'epsilon': {
        'initial_value': 0.5,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': None
    }
    
}
Q_tdlr, V_tdlr, policy_success_tdlr, return_reward_tdlr, policy_success_rate_tdlr = run_tests(n_tests=30,method=sarsa_lambda_control, config=CONFIG)
Q_avg_tdlr = np.mean(Q_tdlr, axis=0)
V_avg_tdlr = np.mean(V_tdlr, axis=0)
RR_avg_tdlr = np.mean(return_reward_tdlr, axis=0)
PSR_avg_tdlr = np.mean(policy_success_rate_tdlr, axis=0) * 100
policy_tdlr = np.argmax(Q_avg_tdlr[-1], axis=1)

# %% [markdown]
# (a)State-value (V) function (20 Points)
# Plot evolution of State-value (V) function with time. Basically, plot V-function vs Episodes for states 0,
# 1, 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true V-function for each of the state in the same plot.

# %%
plot_episode_values(V_avg_tdlr, 'td-lambda-replace-v-est', TRUE_VALUES, config=CONFIG)

# %% [markdown]
# (b)Action state value (Q) function(20 Points)
# Plot evolution of action state value (Q) function with time. Plot Q function vs Episodes for states 0, 1,
# 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true Q-function for each of the state in the same plot.
# (20 Points)

# %%
plot_episode_q_values(Q_avg_tdlr, 'td-lambda-replace-q-est', TRUE_VALUES, config=CONFIG)

# %% [markdown]
# (c) Instances and seeds (5 Points)
# Describe over how many instances of the environments did you average the results? Write about the seeds
# used for each instance.

# %% [markdown]
# The results were averaged for 30 runs of the control method, i.e., 30 instances of the environment, each run had a unique seed, 'seed+run'.

# %% [markdown]
# (d) Environment diagram (5 Points)
# Draw the environment diagram with optimal policy (shown using arrows) obtained using the algorithm.

# %%
draw_maze(policy_tdlr, CONFIG, 'td-lambda-replace-diagram')

# %% [markdown]
# (e) Hyper-parameters (5 Points)
# Write about the hyper-parameters you finally used for the algorithm and describe how did you arrive at
# these set of hyper-params. (5 Points)

# %% [markdown]
# To select the hyperparameters a grid-search was performed over step_size initial_value = (0.1, 0.4) X epsilon initial_value = (0.1, 0.5, 0.8) X lambda = (0.3, 0.5, 0.7)). The control algorithms were run over 5 instances, and relevant plots(Policy Success Rate, Value Estimates, Q-Value Estimates) were visualised and compared to reach at the final selected hyperparameters.
#
# - Step Size: Initial Value = 0.1, Final Value = 0.01, decay_type = 'exponential', decay_stop= 4000
# - Epsilon: Initial Value = 0.5, Final Value = 0.01, decay_type = 'exponential', decay_stop = 4000
# - Lambda: = 0.7

# %% [markdown]
# f) Observations (5 Points)
# Write about your observations from the plots above.

# %% [markdown]
# - Value Estimation Plot:
#     - Plot resembles simple SARSA control algorithm. Although the convergence is slower and noisier, which can be attributed to the trace propogation.
#     - All states except 10, 11 plateau at or reach their true values, by the end of 8000 episodes.
#     - Only benefit over simple SARSA control algorithm from Value State Estimation perspective turns out to be the better estimation of state 11
#     - It can also be observed that due to higher value of lambda, bias is comparitively lower and variance higher.
#
# - Q-Value Estimation Plot:
#     - Unlike SARSA, the control algorithm overestimates the value of state,action pair 11,up. This can be attributed to dilution of error signal as it propogated through multiple steps.
#     - For most other state,action pairs, the values are underestimated (more than SARSA). This is because the traces propogate the living_reward across multiple state,action pairs.

# %% [markdown]
# # **Problem 7: SARSA(λ) Accumulating**
# (40+20+20+5+5+5+5=100 points)
#
# Implement the SARSA(λ) algorithm with Accumulating Eligibility Traces for the Random Maze Environment
# (RME) described above. Use the function definition as given in Lecture slides.
#
# SARSA-Lambda(env, $\gamma$, $\alpha_0$, $\epsilon_0$, $\lambda$, noEpisodes, replaceTrace = False)
# (40 Points)

# %%
def sarsa_lambda_control(environment, config=None):
    """
    Implements the SARSA(λ) algorithm with eligibility traces for a discrete
    Random Maze Environment (RME).

    This function applies SARSA(λ), an on-policy Temporal Difference (TD) control
    algorithm that extends SARSA by incorporating eligibility traces to speed up
    learning. Eligibility traces allow credit assignment to multiple previously
    visited state-action pairs. Both accumulating and replacing traces are
    supported, as specified in the configuration.

    Args:
        environment (gym.Env): Environment with discrete observation and action spaces.
        config (dict): Configuration dictionary containing:
            - max_episodes (int): Number of training episodes.
            - discount_factor (float): Discount factor γ.
            - lambda (float): Eligibility trace decay parameter λ.
            - trace (str): Type of eligibility trace ('accumulating' or 'replacing').
            - step_size (dict): Learning rate (alpha) decay parameters.
            - epsilon (dict): Epsilon-greedy exploration decay parameters.
            - seed (int): Random seed for environment reset.

    Returns:
        Q (np.ndarray): Final learned action-value function of shape (S, A).
        V_s (np.ndarray): State-value estimates derived from Q for each episode.
        policy (np.ndarray): Final greedy policy derived from Q.
        Qs (np.ndarray): History of Q-values across episodes.
        td_target (float): Last computed TD target value.
        policy_success (np.ndarray): Boolean success indicator per episode.
        return_reward (np.ndarray): Total return obtained per episode.
    """


    episodes = config['max_episodes']
    states = config['environment']['total_states']
    actions = config['environment']['total_actions']
    st_dic = config['step_size']
    ep_dic = config['epsilon']
    step_sizes = generate_episode_step_sizes(st_dic['initial_value'], st_dic['final_value'], episodes, 
                                             st_dic['decay_type'], st_dic['decay_stop'])
    epsilons = generate_episode_epsilons(ep_dic['initial_value'], ep_dic['final_value'], episodes, 
                                         ep_dic['decay_type'], ep_dic['decay_stop'])
    Q = np.zeros((states,actions))
    V_s = np.zeros((episodes,states))
    policy = np.array([-1]*states, dtype=int)
    Qs = np.zeros((episodes,states,actions))
    td_target = 0.0
    policy_success = np.zeros(episodes, dtype=bool)
    return_reward = np.zeros(episodes)
    discount = config['discount_factor']
    goal_state = config['environment']['goal_state']
    max_steps = config['max_steps']
    replaceTrace = config['replace_trace']
    l = config['lambda']
    rollouts = config['rollouts']
    policy_success_rate = np.zeros(episodes)
    for e in range(episodes):
        E = np.zeros((states,actions))
        obs, info = environment.reset(options={'max_steps': max_steps})
        state = obs['agent']
        term, trunc = False, False
        action = action_select(state,Q,epsilons[e])
        while not term and not trunc:
            obs, reward, term, trunc, info = environment.step(action)
            next_state = obs['agent']
            next_action = action_select(next_state,Q,epsilons[e])
            td_target = reward
            if not term: 
                td_target+= discount * Q[next_state][next_action]
            td_error = td_target - Q[state][action]
            E[state][action]+=1
            if replaceTrace:
                E  = np.clip(E,0,1)
            Q+= (step_sizes[e]*td_error*E)
            E*=discount*l
            state = next_state
            action = next_action

        
        Qs[e] = Q.copy()
        V_s[e] = np.max(Q,axis=1)
        policy = np.array([
            np.random.choice([a for a in range(actions) if Q[s][a] == np.max(Q[s])])
            for s in range(states)
        ]) 
        policy_success[e], return_reward[e], policy_success_rate[e] = policy_rollout(environment,policy,rollouts,config)
    return Q, V_s, policy, Qs, td_target, policy_success, return_reward, policy_success_rate

# %%
CONFIG = {
    "seed": 101,
    'max_episodes': 8000,
    'discount_factor': 0.99,
    'max_steps': 500,
    'rollouts': 20,
    'lambda':0.7,
    'replace_trace': False, 
    'environment': {
        'total_states': 12,
        'maze_shape': (3, 4),
        'living_reward': -0.04,
        'total_actions': 4,
        'start_state': 8,
        'goal_state': 3,
        'hole_state': 7,
        'goal_reward': 1,
        'hole_reward': -1,
        'wall_state': 5,
    },
    'step_size': {
        'initial_value': 0.1,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': 4000
    },
    'epsilon': {
        'initial_value': 0.3,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': 4000
    }
    
}
Q_tdla, V_tdla, policy_success_tdla, return_reward_tdla, policy_success_rate_tdla = run_tests(n_tests=30,method=sarsa_lambda_control, config=CONFIG)
Q_avg_tdla = np.mean(Q_tdla, axis=0)
V_avg_tdla = np.mean(V_tdla, axis=0)
RR_avg_tdla = np.mean(return_reward_tdla, axis=0)
PSR_avg_tdla = np.mean(policy_success_rate_tdla, axis=0) * 100
policy_tdla = np.argmax(Q_avg_tdla[-1], axis=1)

# %% [markdown]
# (a) State-value (V) function (20 Points)
# Plot evolution of State-value (V) function with time. Basically, plot V-function vs Episodes for states 0,
# 1, 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true V-function for each of the state in the same plot.

# %%
plot_episode_values(V_avg_tdla, 'td-lambda-accumulate-v-est', TRUE_VALUES, CONFIG)

# %% [markdown]
# (b) Action state value (Q) function (20 Points)
# Plot evolution of action state value (Q) function with time. Plot Q function vs Episodes for states 0, 1,
# 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true Q-function for each of the state in the same plot.

# %%
plot_episode_q_values(Q_avg_tdla, 'td-lambda-accumulate-q-est', TRUE_VALUES, CONFIG)

# %% [markdown]
# (c) Instances and seeds (5 Points)
# Describe over how many instances of the environments did you average the results? Write about the seeds
# used for each instance. (5 Points)

# %% [markdown]
# The results were averaged for 30 runs of the control method, i.e., 30 instances of the environment, each run had a unique seed, 'seed+run'.

# %% [markdown]
# (d) Environment diagram (5 Points)
# Draw the environment diagram with optimal policy (shown using arrows) obtained using the algorithm.

# %%
draw_maze(policy_tdla,CONFIG, 'td_lambda-accumulate-diagram')

# %% [markdown]
# (e) Hyper-parameters (5 Points)
# Write about the hyper-parameters you finally used for the algorithm and describe how did you arrive at
# these set of hyper-params.

# %% [markdown]
# To select the hyperparameters a grid-search was performed over step_size initial_value = (0.1, 0.4) X epsilon initial_value = (0.1, 0.5, 0.8) X lambda = (0.3, 0.5, 0.7)). The control algorithms were run over 5 instances, and relevant plots(Policy Success Rate, Value Estimates, Q-Value Estimates) were visualised and compared to reach at the final selected hyperparameters.
#
# - Step Size: Initial Value = 0.1, Final Value = 0.01, decay_type = 'exponential', decay_stop= 4000
# - Epsilon: Initial Value = 0.3, Final Value = 0.01, decay_type = 'exponential', decay_stop = 4000
# - Lambda: = 0.7

# %% [markdown]
# (f) Observations (5 Points)
# Write about your observations from the plots above.

# %% [markdown]
# - Value Estimation Plot:
#     - Plot resembles SARSA lambda replace control algorithm. Although the convergence is smoother and somewhat quicker. It is important to note that epsilon initial_value for SARSA lambda accumulate is chosen as 0.3 (vs 0.5 for lambda replace) making this algorithm greedier and thus faster convergence. Accumulated Traces also help in
#     - All states except 10, 11 plateau at or reach their true values, by the end of 8000 episodes. Due to the location of state 6, it's estimate is noisier than others.
#     - Final Estimate Values identical to SARSA lambda replace.
#
# - Q-Value Estimation Plot:
#     - Most Q-Value estimates are idecntical SARSA lambda replace control, however more smoother and faster to converge.
#     - It is important to note that SARSA lambda accumulate further overestimates the rewards from state 11 across all actions. This can be attributed to further dilution in error signal with larger traces(accumulate).

# %% [markdown]
# # **Problem 8: Q($\lambda$) Replacing**
# ($40+20+20+5+5+5+5=100$ points)
#
# Implement the Q(λ) algorithm with Replacing Eligibility Traces for the Random Maze Environment (RME)
# described above. Use the function definition as given in Lecture slides.
#
# Q-Lambda(env, $\gamma$, $\alpha_0$, $\epsilon_0$, $\lambda$, noEpisodes, replaceTrace = True)
# (40 Points)

# %%
def q_learning_lambda_control(environment, config=None):
    """
    Implements the Q(λ) algorithm with eligibility traces for a discrete
    Random Maze Environment (RME).

    This function applies Q(λ), an off-policy Temporal Difference (TD) control
    algorithm that extends Q-Learning by incorporating eligibility traces.
    Replacing or accumulating eligibility traces can be used to propagate
    temporal-difference errors across multiple previously visited state-action
    pairs. Trace resetting is handled according to whether the behavior policy
    follows the greedy action.

    Args:
        environment (gym.Env): Environment with discrete observation and action spaces.
        config (dict): Configuration dictionary containing:
            - max_episodes (int): Number of training episodes.
            - discount_factor (float): Discount factor γ.
            - lambda (float): Eligibility trace decay parameter λ.
            - trace (str): Type of eligibility trace ('accumulating' or 'replacing').
            - step_size (dict): Learning rate (alpha) decay parameters.
            - epsilon (dict): Epsilon-greedy exploration decay parameters.
            - seed (int): Random seed for environment reset.

    Returns:
        Q (np.ndarray): Final learned action-value function of shape (S, A).
        V_s (np.ndarray): State-value estimates derived from Q for each episode.
        policy (np.ndarray): Final greedy policy derived from Q.
        Qs (np.ndarray): History of Q-values across episodes.
        td_target (float): Last computed TD target value.
        policy_success (np.ndarray): Boolean success indicator per episode.
        return_reward (np.ndarray): Total return obtained per episode.
    """


    episodes = config['max_episodes']
    states = config['environment']['total_states']
    actions = config['environment']['total_actions']
    st_dic = config['step_size']
    ep_dic = config['epsilon']
    step_sizes = generate_episode_step_sizes(st_dic['initial_value'], st_dic['final_value'], episodes, 
                                             st_dic['decay_type'], st_dic['decay_stop'])
    epsilons = generate_episode_epsilons(ep_dic['initial_value'], ep_dic['final_value'], episodes, 
                                         ep_dic['decay_type'], ep_dic['decay_stop'])
    Q = np.zeros((states,actions))
    V_s = np.zeros((episodes,states))
    policy = np.array([-1]*states, dtype=int)
    Qs = np.zeros((episodes,states,actions))
    td_target = 0.0
    policy_success = np.zeros(episodes, dtype=bool)
    return_reward = np.zeros(episodes)
    discount = config['discount_factor']
    goal_state = config['environment']['goal_state']
    max_steps = config['max_steps']
    replaceTrace = config['replace_trace']
    l = config['lambda']
    policy_success_rate = np.zeros(episodes)
    rollouts = config['rollouts']

    for e in range(episodes):
        obs, info = environment.reset(options={'max_steps': max_steps})
        state = obs['agent']
        term, trunc = False, False
        action = action_select(state,Q,epsilons[e])
        E = np.zeros((states,actions))
        while not term and not trunc:
            obs, reward, term, trunc, info = environment.step(action)
            next_state = obs['agent']
            next_action = action_select(next_state,Q,epsilons[e])

            
            if Q[next_state][next_action] == np.max(Q[next_state]):
                s_greedy = True
            else:
                s_greedy = False
            
            td_target = reward
            if not term: 
                td_target+= discount * np.max(Q[next_state])
            td_error = td_target - Q[state][action]
            E[state][action]+=1
            if replaceTrace:
                E = np.clip(E,0,1)
            Q+= (step_sizes[e]*td_error*E)
            if s_greedy:
                E*=discount*l
            else:
                E = np.zeros((states,actions))
            state = next_state
            action = next_action
            
        
        Qs[e] = Q.copy()
        V_s[e] = np.max(Q,axis=1)
        policy = np.array([
            np.random.choice([a for a in range(actions) if Q[s][a] == np.max(Q[s])])
            for s in range(states)
        ]) 
        policy_success[e], return_reward[e], policy_success_rate[e] = policy_rollout(environment,policy,rollouts,config)

    return Q, V_s, policy, Qs, td_target, policy_success, return_reward, policy_success_rate

# %%
CONFIG = {
    "seed": 101,
    'max_episodes': 8000,
    'discount_factor': 0.99,
    'max_steps': 500,
    'rollouts': 20,
    'lambda':0.5,
    'replace_trace': True, 
    'environment': {
        'total_states': 12,
        'maze_shape': (3, 4),
        'living_reward': -0.04,
        'total_actions': 4,
        'start_state': 8,
        'goal_state': 3,
        'hole_state': 7,
        'goal_reward': 1,
        'hole_reward': -1,
        'wall_state': 5,
    },
    'step_size': {
        'initial_value': 0.4,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': 4000
    },
    'epsilon': {
        'initial_value': 0.8,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': 4000
    }
    
}
Q_qlr, V_qlr, policy_success_qlr, return_reward_qlr, policy_success_rate_qlr = run_tests(n_tests=30,method=q_learning_lambda_control, config=CONFIG)
Q_avg_qlr = np.mean(Q_qlr,axis=0)
V_avg_qlr = np.mean(V_qlr, axis=0)
PSR_avg_qlr = np.mean(policy_success_rate_qlr, axis=0) * 100
RR_avg_qlr = np.mean(return_reward_qlr,axis=0)
policy_qlr = np.argmax(Q_avg_qlr[-1], axis = 1)

# %% [markdown]
# (a) State-value (V) function (20 Points)
# Plot evolution of State-value (V) function with time. Basically, plot V-function vs Episodes for states 0,
# 1, 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true V-function for each of the state in the same plot.

# %%
plot_episode_values(V_avg_qlr, 'q-lambda-replace-v-est', TRUE_VALUES, CONFIG)

# %% [markdown]
# (b) Action state value (Q) function (20 Points)
# Plot evolution of action state value (Q) function with time. Plot Q function vs Episodes for states 0, 1,
# 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true Q-function for each of the state in the same plot.

# %%
plot_episode_q_values(Q_avg_qlr, 'q-lambda-replace-q-est', TRUE_VALUES,CONFIG)

# %% [markdown]
# (c) Instances and seeds (5 Points)
# Describe over how many instances of the environments did you average the results? Write about the seeds
# used for each instance.

# %% [markdown]
# The results were averaged for 30 runs of the control method, i.e., 30 instances of the environment, each run had a unique seed, 'seed+run'.

# %% [markdown]
# (d) Environment diagram (5 Points)
# Draw the environment diagram with optimal policy (shown using arrows) obtained using the algorithm.

# %%
draw_maze(policy_qlr,CONFIG,'q-lambda-replace-diagram')

# %% [markdown]
# (e) Hyper-parameters (5 Points)
# Write about the hyper-parameters you finally used for the algorithm and describe how did you arrive at
# these set of hyper-params.

# %% [markdown]
# To select the hyperparameters a grid-search was performed over step_size initial_value = (0.1, 0.4) X epsilon initial_value = (0.1, 0.5, 0.8) X lambda = (0.3, 0.5, 0.7)). The control algorithms were run over 5 instances, and relevant plots(Policy Success Rate, Value Estimates, Q-Value Estimates) were visualised and compared to reach at the final selected hyperparameters.
#
# - Step Size: Initial Value = 0.4, Final Value = 0.01, decay_type = 'exponential', decay_stop= 4000
# - Epsilon: Initial Value = 0.8, Final Value = 0.01, decay_type = 'exponential', decay_stop = 4000
# - Lambda: = 0.5

# %% [markdown]
# (f) Observations (5 Points)
# Write about your observations from the plots above.

# %% [markdown]
# Both Value Estimation Plot and Q-Value Estimation Plot is identical to the plots generated for Q learning with some insignificant differences. This could be attributed to high epsilon value, making the impact of traces negligible.

# %% [markdown]
# # **Problem 9: Q(λ) Accumulating**
#
# ($40+20+20+5+5+5+5=100$ points)
#
# Implement the Q(λ) algorithm with Accumulating Eligibility Traces for the Random Maze Environment (RME)
# described above. Use the function definition as given in Lecture slides.
#
# Q-Lambda(env, $\gamma$, $\alpha_0$, $\epsilon_0$, $\lambda$, noEpisodes, replaceTrace = False)
# (40 Points)

# %%
def q_learning_lambda_control(environment, config=None):
    """
    Implements the Q(λ) algorithm with eligibility traces for a discrete
    Random Maze Environment (RME).

    This function applies Q(λ), an off-policy Temporal Difference (TD) control
    algorithm that extends Q-Learning by incorporating eligibility traces.
    Replacing or accumulating eligibility traces can be used to propagate
    temporal-difference errors across multiple previously visited state-action
    pairs. Trace resetting is handled according to whether the behavior policy
    follows the greedy action.

    Args:
        environment (gym.Env): Environment with discrete observation and action spaces.
        config (dict): Configuration dictionary containing:
            - max_episodes (int): Number of training episodes.
            - discount_factor (float): Discount factor γ.
            - lambda (float): Eligibility trace decay parameter λ.
            - trace (str): Type of eligibility trace ('accumulating' or 'replacing').
            - step_size (dict): Learning rate (alpha) decay parameters.
            - epsilon (dict): Epsilon-greedy exploration decay parameters.
            - seed (int): Random seed for environment reset.

    Returns:
        Q (np.ndarray): Final learned action-value function of shape (S, A).
        V_s (np.ndarray): State-value estimates derived from Q for each episode.
        policy (np.ndarray): Final greedy policy derived from Q.
        Qs (np.ndarray): History of Q-values across episodes.
        td_target (float): Last computed TD target value.
        policy_success (np.ndarray): Boolean success indicator per episode.
        return_reward (np.ndarray): Total return obtained per episode.
    """


    episodes = config['max_episodes']
    states = config['environment']['total_states']
    actions = config['environment']['total_actions']
    st_dic = config['step_size']
    ep_dic = config['epsilon']
    step_sizes = generate_episode_step_sizes(st_dic['initial_value'], st_dic['final_value'], episodes, 
                                             st_dic['decay_type'], st_dic['decay_stop'])
    epsilons = generate_episode_epsilons(ep_dic['initial_value'], ep_dic['final_value'], episodes, 
                                         ep_dic['decay_type'], ep_dic['decay_stop'])
    Q = np.zeros((states,actions))
    V_s = np.zeros((episodes,states))
    policy = np.array([-1]*states, dtype=int)
    Qs = np.zeros((episodes,states,actions))
    td_target = 0.0
    policy_success = np.zeros(episodes, dtype=bool)
    return_reward = np.zeros(episodes)
    discount = config['discount_factor']
    goal_state = config['environment']['goal_state']
    max_steps = config['max_steps']
    replaceTrace = config['replace_trace']
    l = config['lambda']
    policy_success_rate = np.zeros(episodes)
    rollouts = config['rollouts']

    for e in range(episodes):
        obs, info = environment.reset(options={'max_steps': max_steps})
        state = obs['agent']
        term, trunc = False, False
        action = action_select(state,Q,epsilons[e])
        E = np.zeros((states,actions))
        while not term and not trunc:
            obs, reward, term, trunc, info = environment.step(action)
            next_state = obs['agent']
            next_action = action_select(next_state,Q,epsilons[e])

            
            if Q[next_state][next_action] == np.max(Q[next_state]):
                s_greedy = True
            else:
                s_greedy = False
            
            td_target = reward
            if not term: 
                td_target+= discount * np.max(Q[next_state])
            td_error = td_target - Q[state][action]
            E[state][action]+=1
            if replaceTrace:
                E = np.clip(E,0,1)
            Q+= (step_sizes[e]*td_error*E)
            if s_greedy:
                E*=discount*l
            else:
                E = np.zeros((states,actions))
            state = next_state
            action = next_action
            
        
        Qs[e] = Q.copy()
        V_s[e] = np.max(Q,axis=1)
        policy = np.array([
            np.random.choice([a for a in range(actions) if Q[s][a] == np.max(Q[s])])
            for s in range(states)
        ]) 
        policy_success[e], return_reward[e], policy_success_rate[e] = policy_rollout(environment,policy,rollouts,config)

    return Q, V_s, policy, Qs, td_target, policy_success, return_reward, policy_success_rate

# %%
CONFIG = {
    "seed": 101,
    'max_episodes': 8000,
    'discount_factor': 0.99,
    'max_steps': 500,
    'rollouts': 20,
    'lambda':0.7,
    'replace_trace': False, 
    'environment': {
        'total_states': 12,
        'maze_shape': (3, 4),
        'living_reward': -0.04,
        'total_actions': 4,
        'start_state': 8,
        'goal_state': 3,
        'hole_state': 7,
        'goal_reward': 1,
        'hole_reward': -1,
        'wall_state': 5,
    },
    'step_size': {
        'initial_value': 0.1,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': None
    },
    'epsilon': {
        'initial_value': 0.8,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': None
    }
    
}
Q_qla, V_qla, policy_success_qla, return_reward_qla, policy_success_rate_qla = run_tests(n_tests=30,method=q_learning_lambda_control, config=CONFIG)
Q_avg_qla = np.mean(Q_qla,axis=0)
V_avg_qla = np.mean(V_qla, axis=0)
PSR_avg_qla = np.mean(policy_success_rate_qla, axis=0)*100
RR_avg_qla = np.mean(return_reward_qla,axis=0)
policy_qla = np.argmax(Q_avg_qla[-1], axis = 1)

# %% [markdown]
# (a) State-value (V) function (20 Points)
# Plot evolution of State-value (V) function with time. Basically, plot V-function vs Episodes for states 0,
# 1, 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true V-function for each of the state in the same plot.

# %%
plot_episode_values(V_avg_qla, 'q-lambda-accumulate-v-est', TRUE_VALUES, CONFIG)

# %% [markdown]
# (b) Action state value (Q) function (20 Points)
# Plot evolution of action state value (Q) function with time. Plot Q function vs Episodes for states 0, 1,
# 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true Q-function for each of the state in the same plot.

# %%
plot_episode_q_values(Q_avg_qla, 'q-lambda-accumulate-q-est', TRUE_VALUES, CONFIG)

# %% [markdown]
# (c) Instances and seeds (5 Points)
# Describe over how many instances of the environments did you average the results? Write about the seeds
# used for each instance.

# %% [markdown]
# The results were averaged for 30 runs of the control method, i.e., 30 instances of the environment, each run had a unique seed, 'seed+run'.

# %% [markdown]
# (d)Environment diagram (5 Points)
# Draw the environment diagram with optimal policy (shown using arrows) obtained using the algorithm.

# %%
draw_maze(policy_qla, CONFIG, 'q-lambda-accumulate-diagram')

# %% [markdown]
# (e) Hyper-parameters (5 Points)
# Write about the hyper-parameters you finally used for the algorithm and describe how did you arrive at
# these set of hyper-params.

# %% [markdown]
# To select the hyperparameters a grid-search was performed over step_size initial_value = (0.1, 0.4) X epsilon initial_value = (0.1, 0.5, 0.8) X lambda = (0.3, 0.5, 0.7)). The control algorithms were run over 5 instances, and relevant plots(Policy Success Rate, Value Estimates, Q-Value Estimates) were visualised and compared to reach at the final selected hyperparameters.
#
# - Step Size: Initial Value = 0.1, Final Value = 0.01, decay_type = 'exponential', decay_stop= 4000
# - Epsilon: Initial Value = 0.8, Final Value = 0.01, decay_type = 'exponential', decay_stop = 4000
# - Lambda: = 0.7

# %% [markdown]
# (f) Observations (5 Points)
# Write about your observations from the plots above.

# %% [markdown]
# Both Value Estimation Plot and Q-Value Estimation Plot are similar to the plots generated for Q learning. However, the key difference being, For Q-lambda-accumulate control algorithm, the values are much noisier, indicating more variance. This can be a result of large accumulated traces, propogating credit for error to multiple state,action pairs at once.

# %% [markdown]
# # **Problem 10: Dyna-Q**
#
# ($40+20+20+5+5+5+5=100$ points)
#
# Implement the Dyna-Q algorithm for the Random Maze Environment (RME) described above. Use the function
# definition as given in Lecture slides.
#
# Dyna-Q(env, $\gamma$, $\alpha_0$, $\epsilon_0$, noEpisodes, noPlanning)
# (40 Points)

# %%
def dyna_q_control(environment, config=None):
    """
    Implements the Dyna-Q algorithm for a discrete Random Maze Environment (RME).

    This function applies Dyna-Q, a model-based reinforcement learning algorithm
    that integrates direct learning from real environment interactions with
    planning updates using a learned model of the environment. The agent learns
    an action-value function Q(s, a) while simultaneously estimating the
    transition dynamics and reward model, which are used for simulated planning
    updates.

    Args:
        environment (gym.Env): Environment with discrete observation and action spaces.
        config (dict): Configuration dictionary containing:
            - max_episodes (int): Number of training episodes.
            - discount_factor (float): Discount factor γ.
            - no_planning_steps (int): Number of planning updates per real step.
            - step_size (dict): Learning rate (alpha) decay parameters.
            - epsilon (dict): Epsilon-greedy exploration decay parameters.
            - seed (int): Random seed for environment reset.

    Returns:
        Q (np.ndarray): Final learned action-value function of shape (S, A).
        V_s (np.ndarray): State-value estimates derived from Q for each episode.
        policy (np.ndarray): Final greedy policy derived from Q.
        Qs (np.ndarray): History of Q-values across episodes.
        None: Placeholder (no TD target history stored).
        policy_success (np.ndarray): Boolean success indicator per episode.
        return_reward (np.ndarray): Total return obtained per episode.
    """


    episodes = config['max_episodes']
    planning = config['planning']
    states = config['environment']['total_states']
    actions = config['environment']['total_actions']
    st_dic = config['step_size']
    ep_dic = config['epsilon']
    step_sizes = generate_episode_step_sizes(st_dic['initial_value'], st_dic['final_value'], episodes, 
                                             st_dic['decay_type'], st_dic['decay_stop'])
    epsilons = generate_episode_epsilons(ep_dic['initial_value'], ep_dic['final_value'], episodes, 
                                         ep_dic['decay_type'], ep_dic['decay_stop'])
    Q = np.zeros((states,actions))
    V_s = np.zeros((episodes,states))
    policy = np.array([-1]*states, dtype=int)
    Qs = np.zeros((episodes,states,actions))
    policy_success = np.zeros(episodes, dtype=bool)
    return_reward = np.zeros(episodes)
    T = np.zeros((states,actions,states))
    R = np.zeros((states,actions,states))
    discount = config['discount_factor']
    goal_state = config['environment']['goal_state']
    max_steps = config['max_steps']
    rollouts = config['rollouts']
    policy_success_rate = np.zeros(episodes)

    for e in range (episodes):
        obs, info = environment.reset(options={'max_steps': max_steps})
        state = obs['agent']
        term, trunc = False, False
        while not term and not trunc:
            action = action_select(state,Q,epsilons[e])
            obs, reward, term, trunc, info = environment.step(action);
            next_state = obs['agent']
            r_diff = reward - R[state][action][next_state]
            T[state][action][next_state] +=1
            R[state][action][next_state] += (r_diff/T[state][action][next_state])
            td_target = reward
            if not term:
                td_target += (discount*np.max(Q[next_state]))
            td_error = td_target - Q[state][action]
            Q[state][action]+= (step_sizes[e]*td_error)
            s_bp = next_state
            for p in range(planning):
                if np.sum(Q) == 0:
                    break
                s_v, a_t = np.unique(np.argwhere(T)[:, 0]), np.unique(np.argwhere(T)[:, 1]) 
                s = np.random.choice(s_v)
                a = np.random.choice(a_t)
                if np.sum(T[s][a]) == 0: 
                    continue             
                prob = T[s][a]/np.sum(T[s][a]) 
                next_s = np.random.choice(range(states), p=prob)
                r = R[s][a][next_s]
                td_target = r + (discount*np.max(Q[next_s]))
                td_error = td_target - Q[s][a]
                Q[s][a] += (step_sizes[e] * td_error)
            
            state = s_bp
            
        Qs[e] = Q.copy()
        V_s[e] = np.max(Q,axis=1)
        policy = np.array([
            np.random.choice([a for a in range(actions) if Q[s][a] == np.max(Q[s])])
            for s in range(states)
        ]) 
        policy_success[e], return_reward[e], policy_success_rate[e] = policy_rollout(environment,policy, rollouts, config)
    
    return Q, V_s, policy, Qs, None, policy_success, return_reward, policy_success_rate

# %%
CONFIG = {
    "seed": 101,
    'max_episodes': 8000,
    'discount_factor': 0.99,
    'max_steps': 500,
    'rollouts': 20,
    'planning': 25, 
    'environment': {
        'total_states': 12,
        'maze_shape': (3, 4),
        'living_reward': -0.04,
        'total_actions': 4,
        'start_state': 8,
        'goal_state': 3,
        'hole_state': 7,
        'goal_reward': 1,
        'hole_reward': -1,
        'wall_state': 5,
    },
    'step_size': {
        'initial_value': 0.4,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': 4000
    },
    'epsilon': {
        'initial_value': 0.8,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': 4000
    }
    
}
Q_dyq, V_dyq, policy_success_dyq, return_reward_dyq, policy_success_rate_dyq = run_tests(n_tests=30,method=dyna_q_control, config=CONFIG)
Q_avg_dyq = np.mean(Q_dyq,axis=0)
V_avg_dyq = np.mean(V_dyq, axis=0)
PSR_avg_dyq = np.mean(policy_success_rate_dyq, axis=0)*100
RR_avg_dyq = np.mean(return_reward_dyq,axis=0)
policy_dyq = np.argmax(Q_avg_dyq[-1], axis = 1)

# %% [markdown]
# (a)State-value (V) function (20 Points)
# Plot evolution of State-value (V) function with time. Basically, plot V-function vs Episodes for states 0,
# 1, 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true V-function for each of the state in the same plot.

# %%
plot_episode_values(V_avg_dyq, 'dyna-q-v-est', TRUE_VALUES, CONFIG)

# %% [markdown]
# (b) Action state value (Q) function (20 Points)
# Plot evolution of action state value (Q) function with time. Plot Q function vs Episodes for states 0, 1,
# 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true Q-function for each of the state in the same plot.

# %%
plot_episode_q_values(Q_avg_dyq, 'dyna-q-q-est', TRUE_VALUES, CONFIG)

# %% [markdown]
# (c) Instances and seeds (5 Points)
# Describe over how many instances of the environments did you average the results? Write about the seeds
# used for each instance.

# %% [markdown]
# The results were averaged for 30 runs of the control method, i.e., 30 instances of the environment, each run had a unique seed, 'seed+run'.

# %% [markdown]
# (d) Environment diagram (5 Points)
# Draw the environment diagram with optimal policy (shown using arrows) obtained using the algorithm.

# %%
draw_maze(policy_dyq, CONFIG, 'dyna-q-diagram')

# %% [markdown]
# (e) Hyper-parameters (5 Points)
# Write about the hyper-parameters you finally used for the algorithm and describe how did you arrive at
# these set of hyper-params.

# %% [markdown]
# To select the hyperparameters a grid-search was performed over step_size initial_value = (0.1, 0.4) X epsilon initial_value = (0.1, 0.5, 0.8) X planning = (5,15,25)). The control algorithms were run over 5 instances, and relevant plots(Policy Success Rate, Value Estimates, Q-Value Estimates) were visualised and compared to reach at the final selected hyperparameters.
#
# - Step Size: Initial Value = 0.4, Final Value = 0.01, decay_type = 'exponential', decay_stop= 4000
# - Epsilon: Initial Value = 0.8, Final Value = 0.01, decay_type = 'exponential', decay_stop = 4000
# - Plannning: = 25

# %% [markdown]
# (f) Observations (5 Points)
# Write about your observations from the plots above.

# %% [markdown]
# - V Estimation Plot:
#     - Convergance is fast and smooth, attributed to the model based nature of Dyna Q. It practices for 'planning' steps on the model it creates.
#     - This practice makes, Dyna Q require less samples to converge, than other Model Free Techniques, thus making it sample efficient.
#
#
# - Q Estimation Plot:
#     - All q-value estimates have clear separations from initial episodes. Attributed to the planning step of Dyna Q.

# %% [markdown]
# # **Problem 11: Trajectory Learning**
#
# ($40+20+20+5+5+5+5=100$ points)
#
# Implement the Trajectory Learning algorithm for the Random Maze Environment (RME) described above.
# Use the function definition as given in Lecture slides.
#
# TrajectorySampling(env, γ, α0, ϵ0, noEpisodes, maxTrajectory)
# (40 Points)

# %%
def trajectory_sampling_control(environment, config=None):
    """
    Trajectory Sampling (Trajectory Learning) Control Algorithm

    Algorithm (from lecture slides):
        TrajectorySampling(env, γ, α0, ε0, noEpisodes, maxTrajectory)

    Goal:
        Learn an optimal action-value function Q(s, a) by combining:
            - Direct interaction with the environment
            - A learned model of the environment
            - Simulated trajectories sampled from the learned model

    The algorithm alternates between:
        1. Real experience updates (Q-learning)
        2. Planning updates via trajectory sampling

    Inputs:
        environment : Random Maze Environment (RME)
        config      : Dictionary containing γ, α0, ε0, number of episodes,
                      maximum trajectory length, and sampling probability
    """



    episodes = config['max_episodes']
    planning = config['planning']
    states = config['environment']['total_states']
    actions = config['environment']['total_actions']
    st_dic = config['step_size']
    ep_dic = config['epsilon']
    step_sizes = generate_episode_step_sizes(st_dic['initial_value'], st_dic['final_value'], episodes, 
                                             st_dic['decay_type'], st_dic['decay_stop'])
    epsilons = generate_episode_epsilons(ep_dic['initial_value'], ep_dic['final_value'], episodes, 
                                         ep_dic['decay_type'], ep_dic['decay_stop'])
    Q = np.zeros((states,actions))
    V_s = np.zeros((episodes,states))
    policy = np.array([-1]*states, dtype=int)
    Qs = np.zeros((episodes,states,actions))
    policy_success = np.zeros(episodes, dtype=bool)
    return_reward = np.zeros(episodes)
    T = np.zeros((states,actions,states))
    R = np.zeros((states,actions,states))
    discount = config['discount_factor']
    goal_state = config['environment']['goal_state']
    max_steps = config['max_steps']
    rollouts = config['rollouts']
    policy_success_rate = np.zeros(episodes)
    for e in range (episodes):
        obs, info = environment.reset(options={'max_steps': max_steps})
        state = obs['agent']
        term, trunc = False, False
        while not term and not trunc:
            action = action_select(state,Q,epsilons[e])
            obs, reward, term, trunc, info = environment.step(action);
            next_state = obs['agent']
            r_diff = reward - R[state][action][next_state]
            T[state][action][next_state] +=1
            R[state][action][next_state] += (r_diff/T[state][action][next_state])
            td_target = reward
            if not term:
                td_target += (discount*np.max(Q[next_state]))
            td_error = td_target - Q[state][action]
            Q[state][action]+= (step_sizes[e]*td_error)
            s_bp = next_state
            for p in range(planning):
                if np.sum(Q) == 0:
                    break
                a = action_select(state,Q,epsilons[e])
                if np.sum(T[state][a]) == 0:
                    break
                prob = T[state][a]/np.sum(T[state][a]) 
                next_s = np.random.choice(range(states), p=prob)
                r = R[state][a][next_s]
                td_target = r + (discount*np.max(Q[next_s]))
                td_error = td_target - Q[state][a]
                Q[state][a] += (step_sizes[e] * td_error)
                state = next_s
                
                
            state = s_bp
            
        Qs[e] = Q.copy()
        V_s[e] = np.max(Q,axis=1)
        policy = np.array([
            np.random.choice([a for a in range(actions) if Q[s][a] == np.max(Q[s])])
            for s in range(states)
        ]) 
        policy_success[e], return_reward[e], policy_success_rate[e] = policy_rollout(environment,policy, rollouts, config)
    
    return Q, V_s, policy, Qs, None, policy_success, return_reward, policy_success_rate

# %%
CONFIG = {
    "seed": 101,
    'max_episodes': 8000,
    'discount_factor': 0.99,
    'max_steps': 500,
    'rollouts': 20,
    'planning': 15, 
    'environment': {
        'total_states': 12,
        'maze_shape': (3, 4),
        'living_reward': -0.04,
        'total_actions': 4,
        'start_state': 8,
        'goal_state': 3,
        'hole_state': 7,
        'goal_reward': 1,
        'hole_reward': -1,
        'wall_state': 5,
    },
    'step_size': {
        'initial_value': 0.4,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': 4000
    },
    'epsilon': {
        'initial_value': 0.8,
        'final_value': 0.01,
        'decay_type': 'exponential',
        'decay_stop': 4000
    }
    
}
Q_tl, V_tl, policy_success_tl, return_reward_tl, policy_success_rate_tl = run_tests(n_tests=30,method=trajectory_sampling_control, config=CONFIG)
Q_avg_tl = np.mean(Q_tl,axis=0)
V_avg_tl = np.mean(V_tl, axis=0)
PSR_avg_tl = np.mean(policy_success_rate_tl, axis=0)*100
RR_avg_tl = np.mean(return_reward_tl,axis=0)
policy_tl = np.argmax(Q_avg_tl[-1], axis = 1)

# %% [markdown]
# (a) State-value (V) function (20 Points)
# Plot evolution of State-value (V) function with time. Basically, plot V-function vs Episodes for states 0,
# 1, 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true V-function for each of the state in the same plot.

# %%
plot_episode_values(V_avg_tl, 'trajectory-sampling-v-est', TRUE_VALUES, CONFIG)

# %% [markdown]
# (b) Action state value (Q) function (20 Points)
# Plot evolution of action state value (Q) function with time. Plot Q function vs Episodes for states 0, 1,
# 2, 4, 6, 8, 9, 10, 11 in a single plot. Also plot the true Q-function for each of the state in the same plot.

# %%
plot_episode_q_values(Q_avg_tl, 'trajectory-sampling-q-est', TRUE_VALUES, CONFIG)

# %% [markdown]
# (c) Instances and seeds (5 Points)
# Describe over how many instances of the environments did you average the results? Write about the seeds
# used for each instance.

# %% [markdown]
# The results were averaged for 30 runs of the control method, i.e., 30 instances of the environment, each run had a unique seed, 'seed+run'.

# %% [markdown]
# (d)Environment diagram (5 Points)
# Draw the environment diagram with optimal policy (shown using arrows) obtained using the algorithm.

# %%
draw_maze(policy_tl, CONFIG, 'trajectory-sampling-diagram')

# %% [markdown]
# (e) Hyper-parameters (5 Points)
# Write about the hyper-parameters you finally used for the algorithm and describe how did you arrive at
# these set of hyper-params.

# %% [markdown]
# To select the hyperparameters a grid-search was performed over step_size initial_value = (0.1, 0.4) X epsilon initial_value = (0.1, 0.5, 0.8) X planning = (5,15,25)). The control algorithms were run over 5 instances, and relevant plots(Policy Success Rate, Value Estimates, Q-Value Estimates) were visualised and compared to reach at the final selected hyperparameters.
#
# - Step Size: Initial Value = 0.4, Final Value = 0.01, decay_type = 'exponential', decay_stop= 4000
# - Epsilon: Initial Value = 0.8, Final Value = 0.01, decay_type = 'exponential', decay_stop = 4000
# - Plannning: = 15

# %% [markdown]
# (f) Observations (5 Points)
# Write about your observations from the plots above.

# %% [markdown]
# - V Estimation Plot:
#     - a
#     - b
#     - c
#
#
# - Q Estimation Plot:
#     - d
#     - e
#     - f

# %% [markdown]
# # **Problem 12: Comparing Control Algorithms**
#
# ($5+5+5+5+5+5=25$ points)
#
# For SARSA(λ) Replacing, SARSA(λ) Accumulating, Q(λ) Replacing, Q(λ) Accumulating, Dyna-Q, Trajectory Learning implemented above, do the following:
#
# (a) Policy Success Rate (in %) vs Episodes (5 Points)
# For each of the algorithm, in a single plot, plot the evolution of Policy Success Rate (in %) vs Episodes.(5 Points)

# %%
policy_success_rate = np.stack((PSR_avg_tdlr, PSR_avg_tdla, PSR_avg_qlr, PSR_avg_qla, PSR_avg_dyq, PSR_avg_tl), axis=0)
return_reward = np.stack((RR_avg_tdlr, RR_avg_tdla, RR_avg_qlr, RR_avg_qla, RR_avg_dyq, RR_avg_tl), axis=0)
state_values = np.stack((V_avg_tdlr, V_avg_tdla, V_avg_qlr, V_avg_qla, V_avg_dyq, V_avg_tl), axis=0)

# %%
def plot_policy_success(policy_success, title, image_name, config=None):
    plt.plot(figsize=(10,6))
    episodes = np.arange(policy_success.shape[1])
    colors = ['#f54842', '#d4f542', '#1fcc5e', '#0b177d', '#f527e7', '#27f5c5']
    labels = ['SARSA-LAMBDA-REPLACE', 'SARSA-LAMBDA-ACCUMULATE','Q-LEARNING-LAMBDA-REPLACE', 'Q-LEARNING-LAMBDA-ACCUMULATE', 
              'DYNA-Q', 'TRAJECTORY-SAMPLING']
    for i in range(6):
        plt.plot(episodes, policy_success[i], color=colors[i], label=labels[i], linewidth=0.25)
    plt.xlabel('episodes')
    plt.ylabel('policy success rate')
    plt.title(title)
    plt.legend(loc='upper left', bbox_to_anchor=(1.01, 1), borderaxespad=0, framealpha=0.5)
    plt.savefig(f"{image_name}.svg", dpi=300, bbox_inches='tight')
    plt.show()
    
plot_policy_success(policy_success_rate, 'POLICY SUCCESS RATE for different CONTROL Algos', 'PSR-2')

# %% [markdown]
# (b) Policy Success Rate (in %) plot (5 Points)
# What are your observations from the Policy Success Rate (in %) plot.(5 Points)

# %% [markdown]
# [Write your answer here]

# %% [markdown]
# (c) Estimated Expected Return (5 Points)
# For each of the algorithm (in a single plot), plot the Estimated Expected Return (from the start state) vs
# Episodes.

# %%
def plot_expected_return(return_reward, title, image_name, config=None):
    plt.plot(figsize=(10,6))
    episodes = np.arange(return_reward.shape[1])
    colors = ['#f54842', '#d4f542', '#1fcc5e', '#0b177d', '#f527e7', '#27f5c5']
    labels = ['SARSA-LAMBDA-REPLACE', 'SARSA-LAMBDA-ACCUMULATE','Q-LEARNING-LAMBDA-REPLACE', 'Q-LEARNING-LAMBDA-ACCUMULATE', 
              'DYNA-Q', 'TRAJECTORY-SAMPLING']
    for i in range(6):
        plt.plot(episodes, return_reward[i], color=colors[i], label=labels[i])
    plt.xlabel('episodes')
    plt.ylabel('return reward')
    plt.title(title)
    plt.legend(loc='upper left', bbox_to_anchor=(1.01, 1), borderaxespad=0, framealpha=0.5)
    plt.savefig(f"{image_name}.svg", dpi=300, bbox_inches='tight')
    plt.show()
    
plot_expected_return(return_reward, 'EXPECTED RETURN for different CONTROL Algos', 'RR-2')

# %% [markdown]
# d) Observations (5 Points)
# What are your observations for the Estimated Expected Return plot?

# %% [markdown]
# [Write your answer here]

# %% [markdown]
# (e) State-value Function Estimation Error (5 Points)
# For each of the algorithm (in a single plot), plot the State-value Function Estimation Error vs Episodes.
# State-value Function Estimation Error is defined as Mean Absolute Error across all V-function estimates
# (across all states) from the respective optimal value.

# %%
def plot_state_value_error(state_values, title, image_name, TRUE_VALUES, config=None):
    sv_error = np.mean(np.abs(state_values - TRUE_VALUES['V'][None, None, :]), axis=2)
    plt.plot(figsize=(10,6))
    episodes = np.arange(state_values.shape[1])
    colors = ['#f54842', '#d4f542', '#1fcc5e', '#0b177d', '#f527e7', '#27f5c5']
    labels = ['SARSA-LAMBDA-REPLACE', 'SARSA-LAMBDA-ACCUMULATE','Q-LEARNING-LAMBDA-REPLACE', 'Q-LEARNING-LAMBDA-ACCUMULATE', 
              'DYNA-Q', 'TRAJECTORY-SAMPLING']
    for i in range(6):
        plt.plot(episodes, sv_error[i], color=colors[i], label=labels[i])
        
    plt.xlabel('episodes')
    plt.ylabel('state value error')
    plt.title(title)
    plt.legend(loc='upper left', bbox_to_anchor=(1.01, 1), borderaxespad=0, framealpha=0.5)
    plt.savefig(f"{image_name}.svg", dpi=300, bbox_inches='tight')
    plt.show()
    
plot_state_value_error(state_values,'STATE VALUE ESTIMATION ERROR for different CONTROL Algos', 'SVE-2', TRUE_VALUES)

# %% [markdown]
# f) Observations (5 Points)
# What are your observations for the State-value Function Estimation Error plot?

# %% [markdown]
# [Write your answer here]
